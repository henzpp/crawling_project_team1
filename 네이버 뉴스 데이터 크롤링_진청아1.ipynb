# %% [markdown]
# ## 네이버 뉴스 기사 크롤링  (키워드 두개)

# %%
from bs4 import BeautifulSoup 
import urllib
import urllib.request as rq
import pandas as pd

global news_df

def News():
    global keyword, num, news_df, url,page_num
    
    keyword = input('검색 키워드를 입력해주세요')
    keywords = keyword.split()
    keyword1 = keywords[0]
    keyword2 = keywords[1]
    print(keyword1,keyword2)
    keyword1 = urllib.parse.quote(keyword1) #퍼센트인코딩 #URL에 문자를 표현하는 인코딩방법(URL에 한글이 섞이면 오류 발생)
    keyword2 = urllib.parse.quote(keyword2) #퍼센트인코딩 #URL에 문자를 표현하는 인코딩방법(URL에 한글이 섞이면 오류 발생)
    num = int(input('필요한 뉴스기사의 숫자를 입력해주세요'))
    
    news_df = pd.DataFrame(columns=['title','url']) 
    
    page_num=1
    i=0 #크롤링한 기사의 수
    while num > i:
        url = 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query='+keyword1+'+'+keyword2+'&start='+str(page_num)
        html = rq.urlopen(url)
        bs = BeautifulSoup(html,'html.parser')
        texts = bs.find_all(class_='news_tit')

        for text in texts:
            news_df.loc[i,'title'] = text.get_text()
            news_df.loc[i,'url'] = text['href']
            i +=1
            if i == num:
                break
        page_num +=10
        
    news_df.to_csv(r'./news_df_final.csv', index = False)
    return news_df

News()
# Out:
# 검색 키워드를 입력해주세요살해 징역
# 살해 징역
# 필요한 뉴스기사의 숫자를 입력해주세요1000
#                                                title  \
# 0                    제주 중학생 살해 백광석·김시남 징역 30년·27년 확정
# 1                 ‘제주 중학생 살해’ 백광석·김시남, 징역 30년·27년 확정
# 2               동료 수형자 상습폭행 살해한 무기수 또 무기징역...유족 '울분'
# 3                      마포 '주택가 살인' 50대, 징역 30년 불복 항소
# 4                  공주교도소 동료 재소자 살인 20대 '무기징역' 선고(종합)
# ..                                               ...
# 995                  룸메이트 굶기고, 폭행·살해한 20대 남성, 징역 16년
# 996                  카슈끄지 전 변호인, UAE서 탈세 등 혐의로 징역 3년
# 997                   남편 흉기살해 80대 집행유예형.. "심한 치매 증상"
# 998  文, 11명 살해한 조선족엔 "따뜻하게 품어야"… 탈북 어민엔 "살인범" 이유로...
# 999             40대 남성, 이웃집 여성 성폭행·살해 후 살아있는 것처럼 연락해
#
#                                                    url
# 0    https://news.kbs.co.kr/news/view.do?ncd=552017...
# 1    https://news.kmib.co.kr/article/view.asp?arcid...
# 2    https://www.ytn.co.kr/_ln/0115_202207271651440069
# ...
