# %% [markdown]
# ### Keyword Crawling

# %%
import os
import sys
import urllib.request
import pandas as pd

client_id = "E2kR3aLCHEN1UsOGUP7R"
client_secret = "gvdT1t2BQa"

query = urllib.parse.quote(input(r"검색")) # 검색할 단어
#url = "https://openapi.naver.com/v1/search/news.xml?query=" + query # json 결과
url = "https://openapi.naver.com/v1/search/news.xml?query=" + query # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read() #response_body가 이름
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# 검색살해
# ...

# %%
df = pd.read_xml(response_body,xpath='.//item')
df
# Out:
#                                                title  \
# 0  &apos;중학생 잔혹 <b>살해</b>&apos; 백광석·김시남, 징역 30년·2...
# 1  [오피니언] 복수의 화신이 맞게 될 결말에 대하여, 프리츠 랑의 &apos;니벨룽엔...
# 2              R]포항 고양이 연쇄 <b>살해</b> 30대..고양이 학대 유튜버
# 3                                  오일머니 파워, 몸집 더 불린다
# 4              왼쪽도 오른쪽도 싫어 우린 ‘앞으로’ 간다…미국 제3정당 설립 발표
# 5              미, 러에 “수감자 맞교환” 제안…단절 5개월 만에 대화 물꼬 트나
# 6  [포항]&apos;고양이 연쇄 <b>살해</b>&apos; 남성 기소… 학대 유튜브...
# 7     &apos;아다마스&apos; 지성, 계부 죽음 밝힐까...서지혜·허성태와 삼자대면
# 8         &apos;실화탐사대&apos; 아영이 사건→수락산 표지석 연쇄 실종사건까지
# 9            제주 중학생 <b>살해</b> 백광석·김시남… 징역 30년·27년 확정
#
#                                         originallink  \
# 0         http://news.tf.co.kr/read/life/1955113.htm
# 1  https://www.artinsight.co.kr/news/view.php?no=...
# 2       http://andongmbc.co.kr/adboard/NewsView59276
# 3  https://www.khan.co.kr/sports/golf/article/202...
# 4  https://www.khan.co.kr/world/america/article/2...
# 5  https://www.khan.co.kr/world/world-general/art...
# ...

# %%
df1 = df.drop(['link'], axis=1)
df1.to_csv('C:\\Users\\lynn5\\Documents\\GitHub\\hen3\\m2_분석라이브러리활용\\crawling\\df1.csv')
df1
# Out:
#                                                title  \
# 0  &apos;중학생 잔혹 <b>살해</b>&apos; 백광석·김시남, 징역 30년·2...
# 1  [오피니언] 복수의 화신이 맞게 될 결말에 대하여, 프리츠 랑의 &apos;니벨룽엔...
# 2              R]포항 고양이 연쇄 <b>살해</b> 30대..고양이 학대 유튜버
# 3                                  오일머니 파워, 몸집 더 불린다
# 4              왼쪽도 오른쪽도 싫어 우린 ‘앞으로’ 간다…미국 제3정당 설립 발표
# 5              미, 러에 “수감자 맞교환” 제안…단절 5개월 만에 대화 물꼬 트나
# 6  [포항]&apos;고양이 연쇄 <b>살해</b>&apos; 남성 기소… 학대 유튜브...
# 7     &apos;아다마스&apos; 지성, 계부 죽음 밝힐까...서지혜·허성태와 삼자대면
# 8         &apos;실화탐사대&apos; 아영이 사건→수락산 표지석 연쇄 실종사건까지
# 9            제주 중학생 <b>살해</b> 백광석·김시남… 징역 30년·27년 확정
#
#                                         originallink  \
# 0         http://news.tf.co.kr/read/life/1955113.htm
# 1  https://www.artinsight.co.kr/news/view.php?no=...
# 2       http://andongmbc.co.kr/adboard/NewsView59276
# 3  https://www.khan.co.kr/sports/golf/article/202...
# 4  https://www.khan.co.kr/world/america/article/2...
# 5  https://www.khan.co.kr/world/world-general/art...
# ...

# %%
import pandas as pd
from bs4 import BeautifulSoup
import urllib
import urllib.request as rq


df2 = pd.DataFrame(columns=['title','url','description'])
url = 'https://search.naver.com/search.naver?where=news&ie=utf8&sm=nws_hty&query='+query+'&start='+str(page_num)

# %%
from bs4 import BeautifulSoup 
import urllib
import urllib.request as rq
import pandas as pd

global news_df

def News():
    global keyword, num, news_df, url,page_num
    
    keyword = input('검색 키워드를 입력해주세요')
    keyword = urllib.parse.quote(keyword) #퍼센트인코딩 #URL에 문자를 표현하는 인코딩방법(URL에 한글이 섞이면 오류 발생)
    num = int(input('필요한 뉴스기사의 숫자를 입력해주세요'))
    
    news_df = pd.DataFrame(columns=['title','url']) 
    
    page_num=1
    i=0 #크롤링한 기사의 수
    while num > i:
        url = 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query='+keyword+'&start='+str(page_num)
        html = rq.urlopen(url)
        bs = BeautifulSoup(html,'html.parser')
        texts = bs.find_all(class_='news_tit')

        for text in texts:
            news_df.loc[i,'title'] = text.get_text()
            news_df.loc[i,'url'] = text['href']
            i +=1
            if i == num:
                break
        page_num +=10
    return news_df

df2 = News()
# Out:
# 검색 키워드를 입력해주세요살해
# 필요한 뉴스기사의 숫자를 입력해주세요100

# %%
df2
# Out:
#                                          title  \
# 0              제주 중학생 살해 백광석·김시남 징역 30년·27년 확정
# 1               이혼 요구한 아내 살해 혐의 50대 남성, 현행범 체포
# 2         동료 수형자 상습폭행 살해한 무기수 또 무기징역...유족 '울분'
# 3              "왜 전 남친과 비교해" 여자친구 살해한 20대 긴급체포
# 4            끝까지 책임 전가…제주 중학생 살해범들 '중형' 확정[영상]
# ..                                         ...
# 95     "귀신에 빙의돼 살해했다"…부모 살해 정신질환 경력 30대 딸 '구속'
# 96  태영호 "북송어민, 살인 안했는데 죽였다고 자백했을까" 살해 부정론 '신중'
# 97         부모 찾아와 칼 들고 살해한 딸…경찰 보더니 "저 XX도 빙의"
# 98    거동도 제대로 못하는 아버지를…부모집 찾아가 살해하고 달아난 30대 여성
# 99           6살 아들 살해한 의정부 부부, 반려동물 3마리는 살려준 듯
#
#                                                   url
# 0   https://news.kbs.co.kr/news/view.do?ncd=552017...
# 1   http://www.newsis.com/view/?id=NISX20220728_00...
# 2   https://www.ytn.co.kr/_ln/0115_202207271651440069
# 3   http://mbn.mk.co.kr/pages/news/newsView.php?ca...
# 4            https://www.nocutnews.co.kr/news/5794153
# ..                                                ...
# ...

# %%
df2.to_csv('C:\\Users\\lynn5\\Documents\\GitHub\\hen3\\m2_분석라이브러리활용\\crawling\\df2.csv')

# %%
from bs4 import BeautifulSoup 
import urllib
import urllib.request as rq
import pandas as pd

global news_df

def News():
    global keyword, num, news_df, url,page_num
    
    keyword = input('검색 키워드를 입력해주세요')
    keyword = urllib.parse.quote(keyword) #퍼센트인코딩 #URL에 문자를 표현하는 인코딩방법(URL에 한글이 섞이면 오류 발생)
    num = int(input('필요한 뉴스기사의 숫자를 입력해주세요'))
    
    news_df = pd.DataFrame(columns=['title','url']) 
    
    page_num=1
    i=0 #크롤링한 기사의 수
    while num > i:
        url = 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query='+keyword+'&start='+str(page_num)
        html = rq.urlopen(url)
        bs = BeautifulSoup(html,'html.parser')
        texts = bs.find_all(class_='news_tit')

        for text in texts:
            news_df.loc[i,'title'] = text.get_text()
            news_df.loc[i,'url'] = text['href']
            i +=1
            if i == num:
                break
        page_num +=10
    return news_df

df3 = News()
df3
# Out:
# 검색 키워드를 입력해주세요살해
# 필요한 뉴스기사의 숫자를 입력해주세요1000
#                                      title  \
# 0          제주 중학생 살해 백광석·김시남 징역 30년·27년 확정
# 1           이혼 요구한 아내 살해 혐의 50대 남성, 현행범 체포
# 2     동료 수형자 상습폭행 살해한 무기수 또 무기징역...유족 '울분'
# 3          "왜 전 남친과 비교해" 여자친구 살해한 20대 긴급체포
# 4        끝까지 책임 전가…제주 중학생 살해범들 '중형' 확정[영상]
# ..                                     ...
# 995     '계곡 살인' 이은해 · 조현수 법정서 "살해 공모 안 했다"
# 996        통일교 “아베 살해범 어머니, 과거 통일교회 신자” 확인
# 997  민주당TF, 통일부 항의 방문…‘탈북 어민 16명 살해’ 놓고 설전
# 998         전 여자친구 살해 후 시신 유기까지..항소심도 무기징역
# 999     사촌형제 부부 2명 살해 무기징역 50대 ‘항소’…다시 법정에
#
#                                                    url
# 0    https://news.kbs.co.kr/news/view.do?ncd=552017...
# 1    http://www.newsis.com/view/?id=NISX20220728_00...
# 2    https://www.ytn.co.kr/_ln/0115_202207271651440069
# 3    http://mbn.mk.co.kr/pages/news/newsView.php?ca...
# 4             https://www.nocutnews.co.kr/news/5794153
# ..                                                 ...
# ...

# %%
df3.to_csv('C:\\Users\\lynn5\\Documents\\GitHub\\hen3\\m2_분석라이브러리활용\\crawling\\naver_news_1000.csv')

# %%
target = df3['title'].values 
title_list = target.tolist()
title = ' '.join(title_list)
title
# Out:
# '제주 중학생 살해 백광석·김시남 징역 30년·27년 확정 이혼 요구한 아내 살해 혐의 50대 남성, 현행범 체포 동료 수형자 상습폭행 살해한 무기수 또 무기징역...유족 \'울분\' "왜 전 남친과 비교해" 여자친구 살해한 20대 긴급체포 끝까지 책임 전가…제주 중학생 살해범들 \'중형\' 확정[영상] 대통령·국회의장 살해 협박 피의자…건강문제로 조사 받지 않고 귀가 부친 시신 냉장고 유기, 알고 보니 ‘존속살해’? 살인죄로 복역 중 교도소서 또 살해…무기징역 두 번 선고 받았다 김연철 “16명 살해 흉악범 풀어주자는 현 정부 주장 동의할 국민 많지 않아” 경찰, 윤석열 대통령·김진표 의장 살해 협박글 작성 10대 용의자 특정 국정원 홈피에 대통령·국회의장 살해협박 ‘간큰 10대’ "윤석열·김진표 살해하겠다" 국정원 홈페이지 도배된 협박글 단순 사망 처리될뻔한 영아살해 규명…검찰 우수사례 선정 ‘감방 동료’ 살해 20대 무기수, 또 무기징역 선고 일본, ‘도쿄 도심서 7명 살해’ 기결수 사형 집행 “살해 의도 없었다?”... ‘마포 살인’ 남성 징역 7년에 女커뮤니티 반발 이혼 요구한 아내 협박·살해 50대…징역 20년 확정 "날 무시해서" 80대 식당 주인 살해한 60대 구속 ‘실화탐사대’ 정창욱 폭행논란→이은해 남편 살해혐의 그 후 [속보]공주교도소 동료 재소자 살해 20대 \'무기징역\' 선고 부산 사상구서 흉기로 여친 살해한 20대 검거 "잔혹 평가는 어려워"…\'마포 데이트폭력\' 살해 30대 징역7년 확정 [포항]\'고양이 연쇄 살해\' 남성 기소… 학대 유튜브도 운영 의정부 \'자녀 살해 후 극단 선택\' 국과수 부검‥"일산화탄소 중독" 《사형을 집행하라!》 펴낸 김태수 변호사 | 어린이 性추행 살해 후 시신 토막... 이혼서류 보냈다고…아내 목 졸라 살해한 남편, 징역 20년 확정 \'16명 살해\' 탈북민…\'북송인가 처벌인가\' 견해 밝힌 한동훈 [TF사진관] 보완수사 요구로 드러난 \'영아살해\'…검찰 우수사례 선정 “왜 내 거래처 가
# ...

# %%
from konlpy.tag import Okt

okt = Okt()
morph = okt.pos(title)  
noun_list = []
for word, tag in morph:
    if (tag=='Noun') & (len(word) > 1): # Noun이고 단어 1글자 이상인것 뽑아줌 의미있눈거! 한글자는 조사자나
        noun_list.append(word)
#print(morph)
print(noun_list)
# Out:
# ['제주', '중학생', '살해', '광석', '김시', '징역', '확정', '이혼', '요구', '아내', '살해', '혐의', '남성', '현행범', '체포', '동료', '수형', '상습', '폭행', '살해', '무기수', '무기징역', '유족', '울분', '남친', '비교', '여자친구', '살해', '긴급', '체포', '책임', '전가', '제주', '중학생', '살해', '중형', '확정', '영상', '대통령', '국회의장', '살해', '협박', '피의자', '건강', '문제', '조사', '귀가', '부친', '시신', '냉장고', '유기', '존속살해', '살인죄', '복역', '교도소', '살해', '무기징역', '선고', '김연', '살해', '흉악', '정부', '주장', '동의', '국민', '경찰', '윤석열', '대통령', '김진표', '의장', '살해', '협박', '작성', '용의자', '특정', '국정원', '홈피', '대통령', '국회의장', '살해', '협박', '윤석열', '김진표', '살해', '국정원', '홈페이지', '도배', '협박', '단순', '사망', '처리', '영아살해', '규명', '검찰', '우수', '사례', '선정', '감방', '동료', '살해', '무기수', '무기징역', '선고', '일본', '도쿄', '도심', '살해', '기결', '사형', '집행', '살해', '의도', '마포', '살인', '남성', '징역', '커뮤니티', '반발', '이혼', '요구', '아내', '협박', '살해', '징역', '확정', '무시', '식당', '주인', '살해', '구속', '실화', '탐사', '정창욱', '폭행', '논란', '이은해', '남편', '살해', '혐의', '속보', '공주교도소', '동료', '재소', '살해', '무기징역', '선고', '부산', '사상구', '흉기', '여친', '살해', '검거', '잔혹', '평가', '마포', '데이트', '폭력', '살해', '
# ...

# %%
from collections import Counter
from matplotlib import rc
import matplotlib.pyplot as plt
import seaborn as sns

rc('font',family='Malgun Gothic') # 한글 폰트 설정
plt.rcParams['axes.unicode_minus'] = False # 마이너스 부호 출력 설정
count = Counter(noun_list)
data = dict(count.most_common())
series = pd.Series(data)
df = pd.DataFrame(series, columns=['cnt'])
df3_1 = df.sort_values(by='cnt',ascending=False)[:20]
df3_1.reset_index(inplace=True)
df3_1
# Out:
#    index  cnt
# 0     살해  965
# 1     징역  182
# 2     아내   91
# 3     어민   91
# 4     체포   87
# 5     부모   87
# 6     흉기   82
# 7     경찰   78
# 8     남성   77
# 9     여성   75
# 10    아들   73
# 11    북송   67
# 12    남편   65
# 13    협박   64
# 14    탈북   59
# 15    시신   57
# 16    검거   55
# 17    동료   53
# 18    긴급   48
# 19    선고   47

# %%
df3_1.value_counts()
# Out:
# index  cnt
# 거짓     29     1
# 용의자    30     1
# 조사     22     1
# 정부     31     1
# 자녀     38     1
#              ..
# 보고     13     1
# 범행     17     1
# 발표     28     1
# 무시     18     1
# 흉악     18     1
# Length: 100, dtype: int64

# %%
import pandas as pd

df3 = pd.read_csv('C:\\Users\\lynn5\\Documents\\GitHub\\hen3\\m2_분석라이브러리활용\\crawling\\naver_news_1000.csv')
df3
# Out:
#      Unnamed: 0                                  title  \
# 0             0        제주 중학생 살해 백광석·김시남 징역 30년·27년 확정
# 1             1         이혼 요구한 아내 살해 혐의 50대 남성, 현행범 체포
# 2             2   동료 수형자 상습폭행 살해한 무기수 또 무기징역...유족 '울분'
# 3             3        "왜 전 남친과 비교해" 여자친구 살해한 20대 긴급체포
# 4             4      끝까지 책임 전가…제주 중학생 살해범들 '중형' 확정[영상]
# ..          ...                                    ...
# 995         995     '계곡 살인' 이은해 · 조현수 법정서 "살해 공모 안 했다"
# 996         996        통일교 “아베 살해범 어머니, 과거 통일교회 신자” 확인
# 997         997  민주당TF, 통일부 항의 방문…‘탈북 어민 16명 살해’ 놓고 설전
# 998         998         전 여자친구 살해 후 시신 유기까지..항소심도 무기징역
# 999         999     사촌형제 부부 2명 살해 무기징역 50대 ‘항소’…다시 법정에
#
#                                                    url
# 0    https://news.kbs.co.kr/news/view.do?ncd=552017...
# 1    http://www.newsis.com/view/?id=NISX20220728_00...
# 2    https://www.ytn.co.kr/_ln/0115_202207271651440069
# 3    http://mbn.mk.co.kr/pages/news/newsView.php?ca...
# ...

# %% [markdown]
# ### 여기 밑으로 연습

# %%
from bs4 import BeautifulSoup
import requests
import openpyxl
from openpyxl import Workbook
#from openpyxl.utils.dataframe import dataframe_to_rows
import urllib
import urllib.request as rq
import pandas as pd


wb = Workbook()
sheet = wb.active
sheet.append(['발행일','언론사','기사제목','URL','내용'])

keyword = input('검색 키워드를 입력해주세요')
keyword = urllib.parse.quote(keyword) #퍼센트인코딩 #URL에 문자를 표현하는 인코딩방법(URL에 한글이 섞이면 오류 발생)
num = int(input('필요한 뉴스기사의 숫자를 입력해주세요'))

headers = { "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) Chrome/98.0.4758.102" }

#1, 11, 21....91
for page in range(1,1630,10):

    #Get 요청, naver 서버에 대화 시도
    response = requests.get('https://search.naver.com/search.naver?where=news&sm=tab_jum&query='+keyword+'&start='+str(num))
    #네이버에서 html 제공, text 메소드로 태그 내 텍스트만 추출
    html = response.text

    #html 번역선생님으로 수프 만듦
    soup = BeautifulSoup(html, 'html.parser')
    news = soup.select('div.news_wrap.api_ani_send')
    for n in news:
        title = n.select_one('a.news_tit').text
        press = n.select_one('a.info.press').text
        #date = n.select_one('span.info').text
        
        try:
            url = n.select_one('div.info_group > a:nth-of-type(2)')['href']
        except: 
            continue
        article = requests.get(url,headers = headers)
        article_html = BeautifulSoup(article.text,"html.parser")
            
        try:
            date = article_html.select_one('div.sponsor > span.t11').text  
        except:
            continue
        try:
            content = article_html.select_one('div.content > div#articleBody > div#articleBodyContents').text
        except:
            continue
        sheet.append([date, press, title,url, content])
            
    



#간격조절
sheet.column_dimensions['A'].width = 10
sheet.column_dimensions['B'].width = 10
sheet.column_dimensions['C'].width = 30
sheet.column_dimensions['D'].width = 40
sheet.column_dimensions['E'].width = 50
wb.save(filename='march.xlsx')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 15>()
#      12 sheet = wb.active
#      13 sheet.append(['발행일','언론사','기사제목','URL','내용'])
# ---> 15 keyword = input('검색 키워드를 입력해주세요')
#      16 keyword = urllib.parse.quote(keyword) #퍼센트인코딩 #URL에 문자를 표현하는 인코딩방법(URL에 한글이 섞이면 오류 발생)
#      17 num = int(input('필요한 뉴스기사의 숫자를 입력해주세요'))
#
# File C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py:1075, in Kernel.raw_input(self, prompt)
#    1071 if not self._allow_stdin:
#    1072     raise StdinNotImplementedError(
#    1073         "raw_input was called, but this frontend does not support input requests."
#    1074     )
# -> 1075 return self._input_request(
#    1076     str(prompt),
#    1077     self._parent_ident["shell"],
#    1078     self.get_parent("shell"),
#    1079     password=False,
#    1080 )
#
# ...

# %%
import pandas as pd

df1000 = pd.read_csv('C:\\Users\\lynn5\\Documents\\GitHub\\hen3\\m2_분석라이브러리활용\\crawling\\crawling_project_team_1\\march.csv', encoding='cp949')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [4], in <cell line: 3>()
#       1 import pandas as pd
# ----> 3 df1000 = pd.read_csv('C:\\Users\\lynn5\\Documents\\GitHub\\hen3\\m2_분석라이브러리활용\\crawling\\crawling_project_team_1\\march.csv', encoding='cp949')
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
import sys, os
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
import selenium
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from datetime import datetime, timedelta
from pandas import DataFrame
import time
from openpyxl.workbook import Workbook

sleep_sec = 0.5

wb = Workbook()

# User-Agent를 입력해주세요.
headers = {'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36'}
path = 'C:/Users/lynn5/Documents/chromedriver_win32/chromedriver.exe'

# 날짜 지정
query = '살해'
today = datetime.today().strftime("%Y.%m.%d")
oneweek = (datetime.today() - timedelta(7)).strftime("%Y.%m.%d")

def crawling_main_text(url):

    req = requests.get(url, headers = headers)
    req.encoding = None
    soup = BeautifulSoup(req.text, 'html.parser')
    
    # 경향신문
    # if ('khan' in url):
    #     content_of_article = soup.select('div.art_body')
        
    #     str_list = []
    #     for item in content_of_article:
    #         string_item = item.find_all("p", {"class": "content_text"})
    #         str_list.append(string_item)
        
    #     text = " ".join(str_list)
        
    # 국민일보
    if '://news.kmib' in url: 
        text = soup.find('div', {'class' : 'tx'}).text
        date = soup.find('span', {'class': 't11'}).text
        date = date[0:10]
        
    # 내일신문
    elif 'naeil.com' in url:
        text = soup.find('div', {'class' : 'article'}).text
        date = soup.find('div', {'class': 'articleArea'}).find('div', {'class': 'date'}).text
        date = date[0:10]
        
    # 동아일보
    elif 'donga.com' in url:
        text = soup.find('div', {'class' : 'article_txt'}).text
        date = soup.find('span', {'class': 'date01'}).text
        date = date[3:13]
        
    # 매일일보
    elif 'm-i.kr' in url:
        text = soup.find('div', {'itemprop' : 'articleBody'}).text
        date = soup.find('div', {'class': 'info-text'}).find_all('li')[1].text
        date = date[4:14]
    
    # 문화일보
    # elif 'munhwa.com' in url:
    #     text = soup.find('div', {'id' : 'NewsAdContent'}).text
    #     date = soup.find_all('td', {'align': 'right'})[15].text
    #     date = date[3:14]
        
    # 서울신문
    elif 'seoul.co.kr' in url:
        text = soup.find('div', {'itemprop' : 'articleBody'}).text
        date = soup.find('span', {'itemprop': 'datePublished'}).text
        date = date[0:10]
        
    # 세계일보
    elif 'segye.com' in url:
        text = soup.find('article', {'class' : 'viewBox2'}).text
        date = soup.find('p', {'class': 'viewInfo'}).text
        date = date[5:15]
    
    # 아시아투데이
    elif 'asiatoday' in url:
        text = soup.find('div', {'class' : 'news_bm'}).text
        date = soup.find('span', {'class': 'wr_day'}).text
        date = date[5:17]
    
    # 전국매일신문
    elif 'jeonmae' in url:
        text = soup.find('div', {'itemprop' : 'articleBody'}).text
        date = soup.find('div', {'class': 'info-text'}).find_all('li')[1].text
        date = date[4:14]
    
    # 조선일보
    # elif 'chosun' in url:
    #     text = soup.find('section', {'class': 'article-body'}).text
    #     date = soup.find_all('span', {'class': 'font--size-sm-14.font--size-md-14.text--grey-60'})[0][1].text
    #     date = date[0:10]
        
    # 중앙일보
    elif 'joongang.co.kr' in url:
        text = soup.find('div', {'itemprop' : 'articleBody'}).text
        date = soup.find('div', {'class': 'time_bx'}).text
        date = date[4:14]
        
    # 천지일보
    elif 'newscj' in url:
        text = soup.find('div', {'itemprop' : 'articleBody'}).text
        date = soup.find('div', {'class': 'info-text'}).find_all('li')[1].text
        date = date[4:14]
        
    # 한겨레
    elif 'hani' in url:
        text = soup.find('div', {'itemprop' : 'articleBody'}).text
        date = soup.find('p', {'class': 'date-time'}).text
        date = date[4:14]
        
    # 한국일보
    elif 'hankookilbo' in url:
        text = soup.find('div', {'itemprop' : 'articleBody'}).text
        date = soup.find('div', {'class': 'info'}).find('dd').text
        date = date[0:10]
        
    # 그 외
    else:
        text == None
        
    return (text.replace('\n','').replace('\r','').replace('<br>','').replace('\t',''), date)


press_nms = ['국민일보', '내일신문', '동아일보', '매일일보', '서울신문', '세계일보', '아시아투데이', '전국매일신문', '중앙일보', '천지일보', '한겨레', '한국일보']


def news_crawling(press_nm):
    
    service = Service(executable_path=ChromeDriverManager().install())
    browser = webdriver.Chrome(service=service)
    driver = webdriver.Chrome(ChromeDriverManager().install())

    print('검색할 언론사 : {}'.format(press_nm))


    print('브라우저를 실행시킵니다(자동 제어)\n')

    news_url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query={0}&sort=1&photo=0&field=0&pd=1&ds={1}&de={2}'.format(query, oneweek, today)
    browser.get(news_url)
    time.sleep(sleep_sec)


    ################# 언론사 선택 #################
    print('설정한 언론사를 선택합니다.\n')

    bx_press = browser.find_element_by_xpath('//div[@role="listbox" and @class="api_group_option_sort _search_option_detail_wrap"]//li[@class="bx press"]')

    # 언론사 분류순 클릭
    press_tablist = bx_press.find_elements_by_xpath('.//div[@role="tablist" and @class="option"]/a')
    press_tablist[1].click()
    time.sleep(sleep_sec)

    # 언론사 분류 선택
    bx_group = bx_press.find_elements_by_xpath('.//div[@class="api_select_option type_group _category_select_layer"]/div[@class="select_wrap _root"]')[0]

    press_kind_bx = bx_group.find_elements_by_xpath('.//div[@class="group_select _list_root"]')[0]
    press_kind_btn_list = press_kind_bx.find_elements_by_xpath('.//ul[@role="tablist" and @class="lst_item _ul"]/li/a')


    for press_kind_btn in press_kind_btn_list:
        
        # 언론사 종류를 순차적으로 클릭
        press_kind_btn.click()
        time.sleep(sleep_sec)
        
        # 언론사 선택
        press_slct_bx = bx_group.find_elements_by_xpath('.//div[@class="group_select _list_root"]')[1]
        press_slct_btn_list = press_slct_bx.find_elements_by_xpath('.//ul[@role="tablist" and @class="lst_item _ul"]/li/a')
        press_slct_btn_list_nm = [psl.text for psl in press_slct_btn_list]
        
        # 언론사 이름 딕셔너리 생성
        press_slct_btn_dict = dict(zip(press_slct_btn_list_nm, press_slct_btn_list))
        
        # 원하는 언론사가 해당 이름 안에 있는 경우 클릭 후 탐색 중지
        if press_nm in press_slct_btn_dict.keys():
            print('<{}> 카테고리에서 <{}>를 찾았으므로 탐색을 종료합니다'.format(press_kind_btn.text, press_nm))
            
            press_slct_btn_dict[press_nm].click()
            time.sleep(sleep_sec)
            
            break
        

    ################# 뉴스 크롤링 #################

    print('\n크롤링을 시작합니다.')

    #####동적 제어로 페이지 넘어가며 크롤링
    news_dict = {}
    idx = 1
    cur_page = 1
    news_num = 100

    while True:

        table = browser.find_element_by_xpath('//ul[@class="list_news"]')
        li_list = table.find_elements_by_xpath('./li[contains(@id, "sp_nws")]')
        area_list = [li.find_element_by_xpath('.//div[@class="news_area"]') for li in li_list]
        a_list = [area.find_element_by_xpath('.//a[@class="news_tit"]') for area in area_list]
    
        for n in a_list[:min(len(a_list), news_num-idx+1)]:
            n_url = n.get_attribute('href')
            news_dict[idx] = {'언론사': press_nm,
                            '타이틀' : n.get_attribute('title'),
                            '발행일자' : crawling_main_text(n_url)[1],
                            '링크' : n_url,
                            '본문' : crawling_main_text(n_url)[0]}
            
            idx += 1
            
        try:
            next_btn = browser.find_element(By.CSS_SELECTOR, 'a.btn_next')
            next_btn.click()
        
            cur_page +=1

            pages = browser.find_element_by_xpath('//div[@class="sc_page_inner"]')
            next_page_url = [p for p in pages.find_elements_by_xpath('.//a') if p.text == str(cur_page)][0].get_attribute('href')

            browser.get(next_page_url)
            time.sleep(sleep_sec)
            
        except:
            print('\n브라우저를 종료합니다.\n' + '=' * 100)
            time.sleep(0.7)
            browser.close()
            break
        
    ################# 데이터 전처리 #################

    print('데이터프레임 변환\n')
    news_df = DataFrame(news_dict).T

    folder_path = os.getcwd()
    xlsx_file_name = '{}_{}.xlsx'.format(query, press_nm)

    news_df.to_excel(xlsx_file_name, index=False)

    print('엑셀 저장 완료 | 경로 : {}\\{}\n'.format(folder_path, xlsx_file_name))
    
    
for pn in press_nms:
    news_crawling(pn)
# Out:
# C:\Users\lynn5\AppData\Local\Temp\ipykernel_15712\1283449317.py:143: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# 검색할 언론사 : 국민일보
# 브라우저를 실행시킵니다(자동 제어)
#
# 설정한 언론사를 선택합니다.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [9], in <cell line: 254>()
#     251     print('엑셀 저장 완료 | 경로 : {}\\{}\n'.format(folder_path, xlsx_file_name))
#     254 for pn in press_nms:
# --> 255     news_crawling(pn)
#
# Input In [9], in news_crawling(press_nm)
#     155 ################# 언론사 선택 #################
#     156 print('설정한 언론사를 선택합니다.\n')
# --> 158 bx_press = browser.find_element_by_xpath('//div[@role="listbox" and @class="api_group_option_sort _search_option_detail_wrap"]//li[@class="bx press"]')
#     160 # 언론사 분류순 클릭
# ...

# %%
# 2021.01.01 - 2021.06.30 네이버 뉴스 url

url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query='+{keyword}+'&sort=1&photo=0&field=0&pd=3&ds='+{date_s}+'&de='+{date_e}+'&start='+{num}

# %%
# 라이브러리
import requests
from bs4 import BeautifulSoup 
import urllib
import urllib.request as rq
import pandas as pd
import requests
import openpyxl
from openpyxl import Workbook
from openpyxl.utils.dataframe import dataframe_to_rows
import re
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager


# 웹드라이버 설정
options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option("useAutomationExtension", False)


# 페이지 url 형식에 맞게 바꾸어 주는 함수 만들기
# 입력된 수를 1, 11, 21, 31 ...만들어 주는 함수
def makePgNum(num):
    if num == 1:
        return num
    elif num == 0:
        return num + 1
    else:
        return num + 9 * (num - 1)
    
    



keyword = input('검색 키워드를 입력해주세요.  > ')
# 원하는 기간 : 2020.20.20의 포멧으로 입력 ~ 부터
date_s = input('원하는 기간의 시작 날짜를 입력해주세요. ex) 2020.02.02  > ')
# 기간 : ~까지
date_e = input('원하는 기간의 마지막 날짜를 입력해주세요. ex) 2020.02.02  > ')
# 페이지 수 10 단위 up
num = int(input('필요한 뉴스기사의 숫자를 입력해주세요.  > '))

keyword = urllib.parse.quote(keyword) #퍼센트인코딩



url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query='+{keyword}+'&sort=1&photo=0&field=0&pd=3&ds='+{date_s}+'&de='+{date_e}+'&start='+{num}

headers = {'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36'}
# Out:
# 검색 키워드를 입력해주세요ㅇ
# 원하는 기간의 시작 날짜를 입력해주세요. ex) 2020.02.02ㅇ
# 원하는 기간의 마지막 날짜를 입력해주세요. ex) 2020.02.02ㅇ
# 필요한 뉴스기사의 숫자를 입력해주세요ㅇ
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [11], in <cell line: 25>()
#      23 date_e = input('원하는 기간의 마지막 날짜를 입력해주세요. ex) 2020.02.02')
#      24 # 페이지 수 10 단위 up
# ---> 25 num = int(input('필요한 뉴스기사의 숫자를 입력해주세요'))
#      28 keyword = urllib.parse.quote(keyword)
#
# ValueError: invalid literal for int() with base 10: 'ㅇ'

# %%
# 라이브러리
from bs4 import BeautifulSoup
import requests
import re
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager


# 웹드라이버 설정
options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option("useAutomationExtension", False)


# 페이지 url 형식에 맞게 바꾸어 주는 함수 만들기
# 입력된 수를 1, 11, 21, 31 ...만들어 주는 함수
def makePgNum(num):
    if num == 1:
        return num
    elif num == 0:
        return num + 1
    else:
        return num + 9 * (num - 1)


  
    
# 크롤링할 url 생성하는 함수 만들기(검색어, 크롤링 시작 페이지, 크롤링 종료 페이지, 날짜)
def makeUrl(keyword, start_pg, end_pg):
    if start_pg == end_pg:
        start_page = makePgNum(start_pg)
        url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query='+str{keyword}+'&sort=1&photo=0&field=0&pd=3&ds='+{date_s}+'&de='+{date_e}+'&start='+str{start_page}
        print("생성url: ", url)
        return url
    else:
        urls = []
        for i in range(start_pg, end_pg + 1):
            page = makePgNum(i)
            url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query='+str{keyword}+'&sort=1&photo=0&field=0&pd=3&ds='+{date_s}+'&de='+{date_e}+'&start='+str{page}            urls.append(url)
        print("생성url: ", urls)
        return urls
    
    
    

##########뉴스크롤링 시작###################

# 검색어 입력
search = input("검색할 키워드를 입력해주세요:")

# 검색 시작할 페이지 입력
page = int(input("\n크롤링할 시작 페이지를 입력해주세요. ex)1(숫자만입력):"))  # ex)1 =1페이지,2=2페이지...
print("\n크롤링할 시작 페이지: ", page, "페이지")
# 검색 종료할 페이지 입력
page2 = int(input("\n크롤링할 종료 페이지를 입력해주세요. ex)1(숫자만입력):"))  # ex)1 =1페이지,2=2페이지...
print("\n크롤링할 종료 페이지: ", page2, "페이지")
# 원하는 기간 시작 : 2020.20.20의 포멧으로 입력
date_s = input('원하는 기간의 시작 날짜를 입력해주세요. ex) 2020.02.02  > ')
# 기간 종료
date_e = input('원하는 기간의 마지막 날짜를 입력해주세요. ex) 2020.02.02  > ')

# naver url 생성
search_urls = makeUrl(search, page, page2)

## selenium으로 navernews만 뽑아오기##

# 버전에 상관 없이 os에 설치된 크롬 브라우저 사용
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.implicitly_wait(3)

# selenium으로 검색 페이지 불러오기 #

naver_urls = []

for i in search_urls:
    driver.get(i)
    time.sleep(1)  # 대기시간 변경 가능

    # 네이버 기사 눌러서 제목 및 본문 가져오기#
    # 네이버 기사가 있는 기사 css selector 모아오기
    a = driver.find_elements(By.CSS_SELECTOR, 'a.info')

    # 위에서 생성한 css selector list 하나씩 클릭하여 본문 url얻기
    for i in a:
        i.click()

        # 현재탭에 접근
        driver.switch_to.window(driver.window_handles[1])
        time.sleep(3)  # 대기시간 변경 가능

        # 네이버 뉴스 url만 가져오기

        url = driver.current_url
        print(url)

        if "news.naver.com" in url:
            naver_urls.append(url)

        else:
            pass
        # 현재 탭 닫기
        driver.close()
        # 다시처음 탭으로 돌아가기(매우 중요!!!)
        driver.switch_to.window(driver.window_handles[0])

print(naver_urls)

###naver 기사 본문 및 제목 가져오기###

# ConnectionError방지
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) Chrome/98.0.4758.102"}

titles = []
contents = []
for i in naver_urls:
    original_html = requests.get(i, headers=headers)
    html = BeautifulSoup(original_html.text, "html.parser")
    # 검색결과확인시
    # print(html)

    # 뉴스 제목 가져오기
    title = html.select("div#ct > div.media_end_head.go_trans > div.media_end_head_title > h2")
    # list합치기
    title = ''.join(str(title))
    # html태그제거
    pattern1 = '<[^>]*>'
    title = re.sub(pattern=pattern1, repl='', string=title)
    titles.append(title)

    # 뉴스 날짜 가져오기
    date = html.select(class_="info")



print(titles)


# 데이터프레임으로 정리(titles,url,contents)
import pandas as pd

news_df = pd.DataFrame({'title': titles, 'link': naver_urls, 'date': dates})

news_df.to_csv('NaverNews_%s.csv' % search, index=False, encoding='utf-8-sig')
# Out:
#   Input In [21]
#     url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query='+str{keyword}+'&sort=1&photo=0&field=0&pd=3&ds='+{date_s}+'&de='+{date_e}+'&start='+str{start_page}
#                                                                                   ^
# SyntaxError: invalid syntax

# %%
# 크롤링시 필요한 라이브러리 불러오기
from bs4 import BeautifulSoup
import requests
import re
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager


# 웹드라이버 설정
options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option("useAutomationExtension", False)


# 페이지 url 형식에 맞게 바꾸어 주는 함수 만들기
# 입력된 수를 1, 11, 21, 31 ...만들어 주는 함수
def makePgNum(num):
    if num == 1:
        return num
    elif num == 0:
        return num + 1
    else:
        return num + 9 * (num - 1)


# 크롤링할 url 생성하는 함수 만들기(검색어, 크롤링 시작 페이지, 크롤링 종료 페이지)
def makeUrl(search, start_pg, end_pg):
    if start_pg == end_pg:
        start_page = makePgNum(start_pg)
        url = "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=" + search + "&start=" + str(
            start_page)
        print("생성url: ", url)
        return url
    else:
        urls = []
        for i in range(start_pg, end_pg + 1):
            page = makePgNum(i)
            url = "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=" + search + "&start=" + str(page)
            urls.append(url)
        print("생성url: ", urls)
        return urls
    
    
    
# 크롤링할 url 생성하는 함수 만들기(검색어, 크롤링 시작 페이지, 크롤링 종료 페이지, 날짜)
def makeUrl(search, start_pg, end_pg):
    if start_pg == end_pg:
        start_page = makePgNum(start_pg)
        url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query='+{keyword}+'&sort=1&photo=0&field=0&pd=3&ds='+{date_s}+'&de='+{date_e}+'&start='+{num}
        print("생성url: ", url)
        return url
    else:
        urls = []
        for i in range(start_pg, end_pg + 1):
            page = makePgNum(i)
            url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query='+{keyword}+'&sort=1&photo=0&field=0&pd=3&ds='+{date_s}+'&de='+{date_e}+'&start='+{num}
            urls.append(url)
        print("생성url: ", urls)
        return urls
    
    
    

##########뉴스크롤링 시작###################

# 검색어 입력
search = input("검색할 키워드를 입력해주세요:")

# 검색 시작할 페이지 입력
page = int(input("\n크롤링할 시작 페이지를 입력해주세요. ex)1(숫자만입력):"))  # ex)1 =1페이지,2=2페이지...
print("\n크롤링할 시작 페이지: ", page, "페이지")
# 검색 종료할 페이지 입력
page2 = int(input("\n크롤링할 종료 페이지를 입력해주세요. ex)1(숫자만입력):"))  # ex)1 =1페이지,2=2페이지...
print("\n크롤링할 종료 페이지: ", page2, "페이지")

# naver url 생성
search_urls = makeUrl(search, page, page2)

## selenium으로 navernews만 뽑아오기##

# 버전에 상관 없이 os에 설치된 크롬 브라우저 사용
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.implicitly_wait(3)

# selenium으로 검색 페이지 불러오기 #

naver_urls = []

for i in search_urls:
    driver.get(i)
    time.sleep(1)  # 대기시간 변경 가능

    # 네이버 기사 눌러서 제목 및 본문 가져오기#
    # 네이버 기사가 있는 기사 css selector 모아오기
    a = driver.find_elements(By.CSS_SELECTOR, 'a.info')

    # 위에서 생성한 css selector list 하나씩 클릭하여 본문 url얻기
    for i in a:
        i.click()

        # 현재탭에 접근
        driver.switch_to.window(driver.window_handles[1])
        time.sleep(3)  # 대기시간 변경 가능

        # 네이버 뉴스 url만 가져오기

        url = driver.current_url
        print(url)

        if "news.naver.com" in url:
            naver_urls.append(url)

        else:
            pass
        # 현재 탭 닫기
        driver.close()
        # 다시처음 탭으로 돌아가기(매우 중요!!!)
        driver.switch_to.window(driver.window_handles[0])

print(naver_urls)

###naver 기사 본문 및 제목 가져오기###

# ConnectionError방지
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) Chrome/98.0.4758.102"}

titles = []
contents = []
for i in naver_urls:
    original_html = requests.get(i, headers=headers)
    html = BeautifulSoup(original_html.text, "html.parser")
    # 검색결과확인시
    # print(html)

    # 뉴스 제목 가져오기
    title = html.select("div#ct > div.media_end_head.go_trans > div.media_end_head_title > h2")
    # list합치기
    title = ''.join(str(title))
    # html태그제거
    pattern1 = '<[^>]*>'
    title = re.sub(pattern=pattern1, repl='', string=title)
    titles.append(title)

    # 뉴스 본문 가져오기

    content = html.select("div#dic_area")

    # 기사 텍스트만 가져오기
    # list합치기
    content = ''.join(str(content))

    # html태그제거 및 텍스트 다듬기
    content = re.sub(pattern=pattern1, repl='', string=content)
    pattern2 = """[\n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction _flash_removeCallback() {}"""
    content = content.replace(pattern2, '')

    contents.append(content)

print(titles)
print(contents)

# 데이터프레임으로 정리(titles,url,contents)
import pandas as pd

news_df = pd.DataFrame({'title': titles, 'link': naver_urls, 'content': contents})

news_df.to_csv('NaverNews_%s.csv' % search, index=False, encoding='utf-8-sig')
# Out:
# 검색할 키워드를 입력해주세요:살해
#
# 크롤링할 시작 페이지를 입력해주세요. ex)1(숫자만입력):5
#
# 크롤링할 시작 페이지:  5 페이지
#
# 크롤링할 종료 페이지를 입력해주세요. ex)1(숫자만입력):1
#
# 크롤링할 종료 페이지:  1 페이지
# 생성url:  []
# C:\Users\lynn5\AppData\Local\Temp\ipykernel_15712\1882005026.py:84: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# []
# []
# []

# %%
from bs4 import BeautifulSoup
import requests
import re
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
