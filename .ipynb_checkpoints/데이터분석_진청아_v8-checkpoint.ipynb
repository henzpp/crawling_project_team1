# %% [markdown]
# # 데이터셋 전처리
#
# - 유사한 뉴스 기사들 제거 (문제: 기사 하나 남기고 유사한것만 제거되는게 아닌 전부 제거가 됨..)
# - 처벌 컬럼 생성 (..형으로 시작하는 단어나, 무기징역, 그리고 징역일 경우 몇년 까지 포함)
# - 정규표현식 후 명사 추출 및 컬럼 생성
# - 피의자 나이대 컬럼 생성
# - 국내로 제한 (국가 이름들이 나열된 리스트를 웹에서 클롤링해서 국가 이름이 언급될 시 제거)
# - 피해자 컬럼 생성 (살인범죄사전)
# - 가해자 컬럼 생성 (살인범죄사전)
# - 피해자와 가해자의 관계를 파악해서 둘 중 하나가 Nan값인 경우 채워놓기 (예를 들어, 피해자가 부모면 가해자가 자식)
# - Nan 값이 없는 행(뉴스기사)들만 추출하여 최종 데이터 프레임 생성

# %% [markdown]
# -----------

# %% [markdown]
# ## 1. 데이터셋 불러오기

# %%
import pandas as pd 

pd.set_option('display.max_colwidth', None)

# %%
df1 = pd.read_csv('./news_df_1.csv', encoding='utf-8', index_col = 0)
df2 = pd.read_csv('./news_df_2.csv', encoding='utf-8', index_col = 0)
df3 = pd.read_csv('./news_df_3.csv', encoding='utf-8', index_col = 0)
df4 = pd.read_csv('./news_df_4.csv', encoding='utf-8', index_col = 0)
df5 = pd.read_csv('./news_df_5.csv', encoding='utf-8', index_col = 0)
df6 = pd.read_csv('./news_df_6.csv', encoding='utf-8', index_col = 0)

# %%
df = pd.concat([df1,df2,df3,df4,df5,df6])

# %%
df.drop(['Unnamed: 0.1'], axis = 1, inplace = True)

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ------------------

# %% [markdown]
# ## 2. 유사 뉴스 기사 제거

# %%
import difflib

# %%
df['index'] = df.index

# %%
df['index'] = df['index'].astype(str)+'$'

# %%
df['index_similarity'] = df['index']+df['title']

# %%
def similarites(row): # change similiar titles to indexs
    similarities_list  = difflib.get_close_matches(row, list(df[df.index_similarity!=row].index_similarity), cutoff = 0.8)
    
    index_lst =[]
    if len(similarities_list) > 1:
        for i in similarities_list:
            similar =  re.findall('^(\d{1,})[$]',i)
            index_lst.append(similar)
            
    return index_lst

# %%
df['title_similar_index'] = df.index_similarity.apply(lambda row : similarites(row))

# %%
dup_list = []
for i in df.title_similar_index:
    dup =  re.findall('\d+',str(i))
    if len(dup) == 0:
        pass
    else:
        dup_list.append(list(map(int, dup))) #숫자로 바꿔줌

# %%
flat_dup_list = [item for sublist in dup_list for item in sublist]

# %%
flat_dup_list = set(flat_dup_list)
len(flat_dup_list)
# Out:
# 3199

# %%
df = df.drop(list(flat_dup_list))

# %% [markdown]
# -----------

# %%
df.iloc[8995]
# Out:
# date                                                2022.06.14.
# title                          "모친 앞서 딸 살해…피해자 모친 정신적 피해도 심리돼야"
# url                    https://www.nocutnews.co.kr/news/5771678
# index                                                     8995$
# index_similarity          8995$"모친 앞서 딸 살해…피해자 모친 정신적 피해도 심리돼야"
# title_similar_index                    [[8895], [8795], [8695]]
# Name: 8995, dtype: object

# %% [markdown]
# # 비슷한 거들 하나씩만 남기고 삭제하는 방법을 모르겠음..

# %%
df.drop(['index','index_similarity','title_similar_index'], axis=1, inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# -------

# %% [markdown]
# ## 3. 처벌

# %%
import re

for i in range(len(df)): 
    punishment = df.loc[i,'title']

    punishment = re.sub('[-=+,#/\?:^.@*\"※~ㆍ!』‘|\(\)\[\]`\'…》\”\“\’·]', ' ', punishment)
    punishment = re.sub('\s{2,}',' ',punishment) 
    punishment =  re.findall('[가-힣]+형\s|사형|무기징역|징역\s*\d*년',punishment)     # 예. 집행유예형 ... 
    punishment = ' '.join(punishment)

    
    df.loc[i,'punish']= punishment

# %% [markdown]
# -----------------

# %% [markdown]
# ## 4. 정규표현식과 명사 (뉴스 핵심 키워드)

# %%
from konlpy.tag import Okt
import re

for i in range(len(df)): # df 의 행 수만큼 for 문 돌린다.
    news = df.loc[i,'title'] # news 컬럼만의 각 값을 순서대로 가져온다.
    news =  re.findall('[가-힣]+|[가-힣]+\d+|\d+[가-힣]+',news)    # 가져온 행의 값에서 정규표현식 수행 # 영어 추가..\w
    news = ' '.join(news) # 위에서는 한글과 숫자만 추출된 요소들이 list 안에 있으니 전부를 하나로 묶어줌, 이때 스페이스로 분리
    news = re.sub('^\s+|\s+$|\s{2,}','',news) # 불필요한 공백들을 전부 제거

    okt = Okt()
    morph = okt.pos(news)
    noun_list = []
    for word, tag in morph:
        if (tag=='Noun') & (len(word) > 1):# 형용사 
            noun_list.append(word)
    noun_list= ' '.join(noun_list)
    
    df.loc[i,'nouns']= noun_list

# %% [markdown]
# ------------

# %% [markdown]
# ----------

# %% [markdown]
# ## 5. 가해자 나이대

# %% [markdown]
# import re
#
# for i in range(len(df)):
#     news = df.loc[i,'title']
#     news =  re.search('살해\w*\s(\d+)[대]',news)
#     if news:
#         news = news.group()
#
#
#     df.loc[i,'age']= news
#
# df.head(30)

# %%
import re

for i in range(len(df)): # df 의 행 수만큼 for 문 돌린다.
    news = df.loc[i,'title'] # news 컬럼만의 각 값을 순서대로 가져온다.
    news =  re.findall('(\d+)[대]',news)    # 가져온 행의 값에서 정규표현식 수행 # 영어 추가..\w
    
    if len(news)== 0:
        news= None
    
    elif len(news) > 1 : # 두개 나오는 경우가 있는데 보통 가해자는 뒷쪽에 나오기 때문에 두번째 것
        news = news[1]
    else:
        news = news[0]

    df.loc[i,'age']= news
    
df.head(30)
# Out:
#            date                                         title  \
# 0   2022.01.31.                   '제2의 자두 사건'...고양이 살해범 잡아주세요
# 1   2022.01.31.                "고양이 꼬리잡고 바닥에 내리쳐 살해"…경찰 수사 착수
# 2   2022.01.31.               이재명, 고양이 ‘두부’ 잔혹 살해에 “사람 향할 수도”
# 3   2022.01.31.        [사건의 재구성]범행 감추려고 피해자 언니까지 살해한 인면수심 30대
# 4   2022.01.30.         [사건의 재구성] 16살 연하 남친 살해한 돌싱녀…"내가 창피해?"
# 5   2022.01.30.           고양이 ‘두부’ 잔혹 살해 범죄에 이재명 “경찰 적극 수사해야”
# 6   2022.01.26.                 16세 연하 남친 흉기 살해 30대 여성 징역 22년
# 7   2022.01.26.             결혼 1달 만에 아내 폭행·살해한 50대에 징역 30년 구형
# 8   2022.01.26.        “내 번호 왜 지워”… 남친 살해한 여성, 무기징역→징역 22년 감형
# 9   2022.01.30.           창원서 고양이 꼬리 잡고 살해…이재명 “경찰의 적극 수사 요청”
# 10  2022.01.28.                  수억원 횡령 들통 나자 점주 살해 직원…징역 13년
# 11  2022.01.28.         70대 마구 때린 190㎝ 20대男…"형 가볍다" 2심서 징역 늘어
# 12  2022.01.30.                이재명, 고양이 학대 살해에 "범죄전담팀 구성해 엄단"
# 13  2022.01.25.             당진 자매 살해범 항소심도 무기징역…유족 “사형 선고했어야”
# 14  2022.01.25.            퇴거 통보에 이웃 흉기 분풀이…50대 살해범 징역 15년 선고
# 15  2022.01.31.            계약금 문제로 흉기 휘두른 50대, 항소심서도 징역 1년6개월
# 16  2022.01.30.       DR콩고 군사법원, 유엔 전문가 납치·살해하고 참수한 51명에 “사형”
# 17  2022.01.26.              “집착 성향 지속”…‘장검’ 부인 살해에 ‘무기징역’ 구형
# 18  2022.01.24.            무릎까지 꿇더니…'세모녀 살해' 김태현, 무기징역에 대법 상고
# 19  2022.01.29.                자해하고 6살 아들 살해 시도한 40대 친모, 집행유예
# 20  2022.01.25.                '자매 살해' 2심도 무기징역…사형 외쳤던 아버지 오열
# 21  2022.01.19.            '세모녀 살해' 2심…무기징역 선고하며 "가석방 안돼"(종합)
# 22  2022.01.29.  [단독] "소파에 소변보며 술주정"…벽돌로 남편 살해한 부인, 2심도 징역 4년
# 23  2022.01.19.            갓 태어난 영아 살해 방조한 30대 남성 2명, 각 징역 3년
# 24  2022.01.25.             당진 자매 살해범 항소심도 무기징역…유족 "어처구니가 없다"
# 25  2022.01.26.      '세 모녀 살해' 혐의 김태현 무기징역에 검찰도 상고… 대법원 최종 판단
# 26  2022.01.27.  '3세 딸 방치·사망' 30대 미혼모, 2심서 징역 15년..."지능지수 낮아"
# 27  2022.01.24.            수익금 안 주자 동업자 살해 시도…1명 징역4년, 2명은 집유
# 28  2022.01.20.                친할머니 살해한 10대 징역형…범행 방조한 동생은 집유
# 29  2022.01.29.              술 마시다 흉기 휘두른 70대 징역 6년…"심신미약 아냐"
#
#                                                                                                                                     url  \
# 0                                                                                     https://www.ytn.co.kr/_ln/0115_202201312029383965
# 1                                                            http://www.newsis.com/view/?id=NISX20220131_0001743534&cID=10812&pID=10800
# 2                                                          http://news.kmib.co.kr/article/view.asp?arcid=0016723451&code=61111111&cp=nv
# 3                                                                                                https://www.news1.kr/articles/?4570950
# 4                                                                                                https://www.news1.kr/articles/?4570040
# 5                                                                    https://www.hani.co.kr/arti/politics/politics_general/1029321.html
# 6                                                           https://www.seoul.co.kr/news/newsView.php?id=20220126500100&wlog_tag3=naver
# 7                                                            http://www.newsis.com/view/?id=NISX20220126_0001738203&cID=10807&pID=10800
# 8   https://biz.chosun.com/topics/law_firm/2022/01/26/CICTF4BSGBGEVFNH2M2SFIA7ZI/?utm_source=naver&utm_medium=original&utm_campaign=biz
# 9                                                         http://www.segye.com/content/html/2022/01/30/20220130506469.html?OutUrl=naver
# 10                                                                                        http://www.fnnews.com/news/202201281044280038
# 11                                                           http://www.newsis.com/view/?id=NISX20220128_0001741876&cID=10201&pID=10200
# 12                                                           http://www.newsis.com/view/?id=NISX20220130_0001743065&cID=10301&pID=10300
# 13                                                                                https://news.kbs.co.kr/news/view.do?ncd=5381164&ref=A
# 14                                                           http://www.newsis.com/view/?id=NISX20220125_0001737143&cID=10201&pID=10200
# 15                                                                                         http://yna.kr/AKR20220128111500055?did=1195m
# 16                                                          https://www.seoul.co.kr/news/newsView.php?id=20220130500059&wlog_tag3=naver
# 17                                                          https://www.seoul.co.kr/news/newsView.php?id=20220126500144&wlog_tag3=naver
# 18                                                                                          https://www.joongang.co.kr/article/25043100
# 19                                                           http://www.newsis.com/view/?id=NISX20220128_0001742149&cID=10807&pID=10800
# 20                                                                  https://news.jtbc.joins.com/article/article.aspx?news_id=NB12044331
# 21                                                           http://www.newsis.com/view/?id=NISX20220119_0001730171&cID=10201&pID=10200
# 22                                                                                       http://news.tf.co.kr/read/national/1915813.htm
# 23                                                           http://www.newsis.com/view/?id=NISX20220119_0001730444&cID=10807&pID=10800
# 24                                                                                 http://news.mk.co.kr/newsRead.php?no=75711&year=2022
# 25                                                                        http://moneys.mt.co.kr/news/mwView.php?no=2022012618098013642
# 26                                                           http://www.newsis.com/view/?id=NISX20220127_0001739441&cID=10201&pID=10200
# 27                                                                                               https://www.news1.kr/articles/?4563390
# 28                                                                                             https://www.nocutnews.co.kr/news/5693406
# 29                                                                                         http://yna.kr/AKR20220128114800051?did=1195m
#
#    index                                 index_similarity title_similar_index  \
# 0     0$                    0$'제2의 자두 사건'...고양이 살해범 잡아주세요                  []
# 1     1$                 1$"고양이 꼬리잡고 바닥에 내리쳐 살해"…경찰 수사 착수                  []
# 2     2$                2$이재명, 고양이 ‘두부’ 잔혹 살해에 “사람 향할 수도”                  []
# 3     3$         3$[사건의 재구성]범행 감추려고 피해자 언니까지 살해한 인면수심 30대                  []
# 4     4$          4$[사건의 재구성] 16살 연하 남친 살해한 돌싱녀…"내가 창피해?"                  []
# 5     5$            5$고양이 ‘두부’ 잔혹 살해 범죄에 이재명 “경찰 적극 수사해야”                  []
# 6     6$                  6$16세 연하 남친 흉기 살해 30대 여성 징역 22년                  []
# 7     9$              9$결혼 1달 만에 아내 폭행·살해한 50대에 징역 30년 구형                  []
# 8    10$        10$“내 번호 왜 지워”… 남친 살해한 여성, 무기징역→징역 22년 감형                  []
# 9    11$           11$창원서 고양이 꼬리 잡고 살해…이재명 “경찰의 적극 수사 요청”                  []
# 10   12$                  12$수억원 횡령 들통 나자 점주 살해 직원…징역 13년                  []
# 11   13$         13$70대 마구 때린 190㎝ 20대男…"형 가볍다" 2심서 징역 늘어                  []
# 12   14$                14$이재명, 고양이 학대 살해에 "범죄전담팀 구성해 엄단"                  []
# 13   15$             15$당진 자매 살해범 항소심도 무기징역…유족 “사형 선고했어야”                  []
# 14   16$            16$퇴거 통보에 이웃 흉기 분풀이…50대 살해범 징역 15년 선고                  []
# 15   17$            17$계약금 문제로 흉기 휘두른 50대, 항소심서도 징역 1년6개월                  []
# 16   18$       18$DR콩고 군사법원, 유엔 전문가 납치·살해하고 참수한 51명에 “사형”                  []
# 17   19$              19$“집착 성향 지속”…‘장검’ 부인 살해에 ‘무기징역’ 구형                  []
# 18   20$            20$무릎까지 꿇더니…'세모녀 살해' 김태현, 무기징역에 대법 상고                  []
# 19   22$                22$자해하고 6살 아들 살해 시도한 40대 친모, 집행유예                  []
# 20   23$                23$'자매 살해' 2심도 무기징역…사형 외쳤던 아버지 오열                  []
# 21   24$            24$'세모녀 살해' 2심…무기징역 선고하며 "가석방 안돼"(종합)                  []
# 22   28$  28$[단독] "소파에 소변보며 술주정"…벽돌로 남편 살해한 부인, 2심도 징역 4년                  []
# 23   29$            29$갓 태어난 영아 살해 방조한 30대 남성 2명, 각 징역 3년                  []
# 24   30$             30$당진 자매 살해범 항소심도 무기징역…유족 "어처구니가 없다"                  []
# 25   31$      31$'세 모녀 살해' 혐의 김태현 무기징역에 검찰도 상고… 대법원 최종 판단                  []
# 26   32$  32$'3세 딸 방치·사망' 30대 미혼모, 2심서 징역 15년..."지능지수 낮아"                  []
# 27   33$            33$수익금 안 주자 동업자 살해 시도…1명 징역4년, 2명은 집유                  []
# 28   34$                34$친할머니 살해한 10대 징역형…범행 방조한 동생은 집유                  []
# 29   36$              36$술 마시다 흉기 휘두른 70대 징역 6년…"심신미약 아냐"                  []
#
#              징역                              nouns   age
# 0                                     자두 사건 고양이 살해   NaN
# 1                         고양이 꼬리 잡고 바닥 살해 경찰 수사 착수   NaN
# 2                           이재명 고양이 두부 잔혹 살해 사람 수도   NaN
# 3                           사건 구성 범행 피해자 언니 살해 인면수    30
# 4                            사건 구성 연하 남친 살해 돌싱 창피해  None
# 5                     고양이 두부 잔혹 살해 범죄 이재명 경찰 적극 수사  None
# 6        징역 22년                  연하 남친 흉기 살해 여성 징역    30
# 7        징역 30년                  결혼 아내 폭행 살해 징역 구형    50
# 8   무기징역 징역 22년             번호 남친 살해 여성 무기징역 징역 감형  None
# 9                  창원 고양이 꼬리 잡고 살해 이재명 경찰 적극 수사 요청  None
# 10       징역 13년               억원 횡령 들통 점주 살해 직원 징역  None
# 11                                           마구 징역    20
# 12                       이재명 고양이 학대 살해 범죄 전담 구성 엄단  None
# 13     무기징역 사형          당진 자매 살해 항소심 무기징역 유족 사형 선고  None
# 14       징역 15년           퇴거 통보 이웃 흉기 분풀이 살해 징역 선고    50
# 15        징역 1년             계약금 문제 흉기 항소심 서도 징역 개월    50
# 16          사형          콩고 군사법원 유엔 전문가 납치 살해 참수 사형  None
# 17         무기징역          집착 성향 지속 장검 부인 살해 무기징역 구형  None
# 18         무기징역            무릎 모녀 살해 김태현 무기징역 대법 상고  None
# 19                             자해 아들 살해 시도 친모 집행유예    40
# 20     무기징역 사형                자매 살해 무기징역 사형 아버지 오열  None
# 21         무기징역               모녀 살해 무기징역 선고 가석방 종합  None
# 22        징역 4년         단독 소파 소변 주정 벽돌 남편 살해 부인 징역  None
# 23        징역 3년                     영아 살해 방조 남성 징역    30
# 24         무기징역          당진 자매 살해 항소심 무기징역 유족 어처구니  None
# 25         무기징역  모녀 살해 혐의 김태현 무기징역 검찰 상고 대법원 최종 판단  None
# 26       징역 15년                  방치 사망 미혼모 징역 지능지수    30
# 27         징역4년              수익금 주자 업자 살해 시도 징역 집유  None
# 28         징역형              할머니 살해 징역형 범행 방조 동생 집유    10
# 29        징역 6년                        흉기 징역 심신 미약    70

# %% [markdown]
# -------------

# %% [markdown]
# ## 6. 국내로 제한
# 1. 제외 대상인 국가 리스트  추출

# %%
#https://ko.wiktionary.org/wiki/%EB%B6%80%EB%A1%9D:%EC%84%B8%EA%B3%84%EC%9D%98_%EB%82%98%EB%9D%BC# Q. 네이버 영화 랭킹 가져와서 첫번째 영화제목을 출력하세요
from bs4 import BeautifulSoup
import re
import pandas
import urllib.request as rq

url = 'https://ko.wiktionary.org/wiki/%EB%B6%80%EB%A1%9D:%EC%84%B8%EA%B3%84%EC%9D%98_%EB%82%98%EB%9D%BC'
html = rq.urlopen(url) # 사이트 열기
bs = BeautifulSoup(html,'html.parser')
countries = bs.find_all('tr') 

country_list = []
for country in countries:
    country=country.find('td') # 첫번째 열에 국가 이름이 있기 때문
    if  country:
        country = country.get_text()
        country = country[:-1] # 이름 마다 끝에 \n 이 있어서 
        country_list.append(country)

country_list.append('아베')
country_list.remove('한국')
country_list.append('중국')

# %% [markdown]
# ###### country_list

# %%
df.head(15)
# Out:
#            date                                   title  \
# 0   2022.01.31.             '제2의 자두 사건'...고양이 살해범 잡아주세요
# 1   2022.01.31.          "고양이 꼬리잡고 바닥에 내리쳐 살해"…경찰 수사 착수
# 2   2022.01.31.         이재명, 고양이 ‘두부’ 잔혹 살해에 “사람 향할 수도”
# 3   2022.01.31.  [사건의 재구성]범행 감추려고 피해자 언니까지 살해한 인면수심 30대
# 4   2022.01.30.   [사건의 재구성] 16살 연하 남친 살해한 돌싱녀…"내가 창피해?"
# 5   2022.01.30.     고양이 ‘두부’ 잔혹 살해 범죄에 이재명 “경찰 적극 수사해야”
# 6   2022.01.26.           16세 연하 남친 흉기 살해 30대 여성 징역 22년
# 7   2022.01.26.       결혼 1달 만에 아내 폭행·살해한 50대에 징역 30년 구형
# 8   2022.01.26.  “내 번호 왜 지워”… 남친 살해한 여성, 무기징역→징역 22년 감형
# 9   2022.01.30.     창원서 고양이 꼬리 잡고 살해…이재명 “경찰의 적극 수사 요청”
# 10  2022.01.28.            수억원 횡령 들통 나자 점주 살해 직원…징역 13년
# 11  2022.01.28.   70대 마구 때린 190㎝ 20대男…"형 가볍다" 2심서 징역 늘어
# 12  2022.01.30.          이재명, 고양이 학대 살해에 "범죄전담팀 구성해 엄단"
# 13  2022.01.25.       당진 자매 살해범 항소심도 무기징역…유족 “사형 선고했어야”
# 14  2022.01.25.      퇴거 통보에 이웃 흉기 분풀이…50대 살해범 징역 15년 선고
#
#                                                                                                                                     url  \
# 0                                                                                     https://www.ytn.co.kr/_ln/0115_202201312029383965
# 1                                                            http://www.newsis.com/view/?id=NISX20220131_0001743534&cID=10812&pID=10800
# 2                                                          http://news.kmib.co.kr/article/view.asp?arcid=0016723451&code=61111111&cp=nv
# 3                                                                                                https://www.news1.kr/articles/?4570950
# 4                                                                                                https://www.news1.kr/articles/?4570040
# 5                                                                    https://www.hani.co.kr/arti/politics/politics_general/1029321.html
# 6                                                           https://www.seoul.co.kr/news/newsView.php?id=20220126500100&wlog_tag3=naver
# 7                                                            http://www.newsis.com/view/?id=NISX20220126_0001738203&cID=10807&pID=10800
# 8   https://biz.chosun.com/topics/law_firm/2022/01/26/CICTF4BSGBGEVFNH2M2SFIA7ZI/?utm_source=naver&utm_medium=original&utm_campaign=biz
# 9                                                         http://www.segye.com/content/html/2022/01/30/20220130506469.html?OutUrl=naver
# 10                                                                                        http://www.fnnews.com/news/202201281044280038
# 11                                                           http://www.newsis.com/view/?id=NISX20220128_0001741876&cID=10201&pID=10200
# 12                                                           http://www.newsis.com/view/?id=NISX20220130_0001743065&cID=10301&pID=10300
# 13                                                                                https://news.kbs.co.kr/news/view.do?ncd=5381164&ref=A
# 14                                                           http://www.newsis.com/view/?id=NISX20220125_0001737143&cID=10201&pID=10200
#
#    index                           index_similarity title_similar_index  \
# 0     0$              0$'제2의 자두 사건'...고양이 살해범 잡아주세요                  []
# 1     1$           1$"고양이 꼬리잡고 바닥에 내리쳐 살해"…경찰 수사 착수                  []
# 2     2$          2$이재명, 고양이 ‘두부’ 잔혹 살해에 “사람 향할 수도”                  []
# 3     3$   3$[사건의 재구성]범행 감추려고 피해자 언니까지 살해한 인면수심 30대                  []
# 4     4$    4$[사건의 재구성] 16살 연하 남친 살해한 돌싱녀…"내가 창피해?"                  []
# 5     5$      5$고양이 ‘두부’ 잔혹 살해 범죄에 이재명 “경찰 적극 수사해야”                  []
# 6     6$            6$16세 연하 남친 흉기 살해 30대 여성 징역 22년                  []
# 7     9$        9$결혼 1달 만에 아내 폭행·살해한 50대에 징역 30년 구형                  []
# 8    10$  10$“내 번호 왜 지워”… 남친 살해한 여성, 무기징역→징역 22년 감형                  []
# 9    11$     11$창원서 고양이 꼬리 잡고 살해…이재명 “경찰의 적극 수사 요청”                  []
# 10   12$            12$수억원 횡령 들통 나자 점주 살해 직원…징역 13년                  []
# 11   13$   13$70대 마구 때린 190㎝ 20대男…"형 가볍다" 2심서 징역 늘어                  []
# 12   14$          14$이재명, 고양이 학대 살해에 "범죄전담팀 구성해 엄단"                  []
# 13   15$       15$당진 자매 살해범 항소심도 무기징역…유족 “사형 선고했어야”                  []
# 14   16$      16$퇴거 통보에 이웃 흉기 분풀이…50대 살해범 징역 15년 선고                  []
#
#              징역                            nouns   age
# 0                                   자두 사건 고양이 살해   NaN
# 1                       고양이 꼬리 잡고 바닥 살해 경찰 수사 착수   NaN
# 2                         이재명 고양이 두부 잔혹 살해 사람 수도   NaN
# 3                         사건 구성 범행 피해자 언니 살해 인면수    30
# 4                          사건 구성 연하 남친 살해 돌싱 창피해  None
# 5                   고양이 두부 잔혹 살해 범죄 이재명 경찰 적극 수사  None
# 6        징역 22년                연하 남친 흉기 살해 여성 징역    30
# 7        징역 30년                결혼 아내 폭행 살해 징역 구형    50
# 8   무기징역 징역 22년           번호 남친 살해 여성 무기징역 징역 감형  None
# 9                창원 고양이 꼬리 잡고 살해 이재명 경찰 적극 수사 요청  None
# 10       징역 13년             억원 횡령 들통 점주 살해 직원 징역  None
# 11                                         마구 징역    20
# 12                     이재명 고양이 학대 살해 범죄 전담 구성 엄단  None
# 13     무기징역 사형        당진 자매 살해 항소심 무기징역 유족 사형 선고  None
# 14       징역 15년         퇴거 통보 이웃 흉기 분풀이 살해 징역 선고    50

# %% [markdown]
# 2. 국가 이름이 언급된 뉴스 제목들은 제거

# %%
index = 0
delete_rows = []
for i in range(len(df)): 
    nouns = df.loc[i,'nouns'] #제목 내에 명사들
    nouns = nouns.split()
    for noun in nouns: # 각 명사 살펴보기
        if noun in country_list: # 리스트에 있으면 제거 요소로 추가
            print(noun)
            delete_rows.append(index)
        else: 
            pass
        
    index +=1

print(delete_rows)
df.drop(set(delete_rows), inplace=True) # 한 제목에 여러 국가 관련 단어 들어있을 수 잇으니 unique 로 
df
# Out:
# 과테말라
# 중국
# 카자흐스탄
# 카자흐스탄
# 베트남
# 과테말라
# 중국
# 중국
# 중국
# 멕시코
# 중국
# 파키스탄
# 프랑스
# 피지
# 프랑스
# 베트남
# 카자흐스탄
# 파키스탄
# 프랑스
# 피지
# 프랑스
# 베트남
# 카자흐스탄
# 독일
# 온두라스
# 독일
# 온두라스
# 독일
# 온두라스
# 독일
# 온두라스
# 독일
# 온두라스
# 독일
# 온두라스
# [74, 78, 88, 111, 220, 225, 230, 246, 251, 268, 291, 307, 316, 327, 435, 579, 582, 595, 604, 615, 722, 866, 869, 5265, 5321, 5391, 5447, 5491, 5547, 5591, 5647, 5691, 5747, 5791, 5847]
#              date                                    title  \
# 0     2022.01.31.              '제2의 자두 사건'...고양이 살해범 잡아주세요
# 1     2022.01.31.           "고양이 꼬리잡고 바닥에 내리쳐 살해"…경찰 수사 착수
# 2     2022.01.31.          이재명, 고양이 ‘두부’ 잔혹 살해에 “사람 향할 수도”
# 3     2022.01.31.   [사건의 재구성]범행 감추려고 피해자 언니까지 살해한 인면수심 30대
# 4     2022.01.30.    [사건의 재구성] 16살 연하 남친 살해한 돌싱녀…"내가 창피해?"
# ...           ...                                      ...
# 5870  2022.06.14.         "모친 앞서 딸 살해…피해자 모친 정신적 피해도 심리돼야"
# 5871  2022.06.26.        '발달장애 자녀 살해' 친모들… 같은 죄, 다른 벌 이유는?
# 5872  2022.06.20.      술취해 12년 사실혼 끝에 헤어지자 흉기 휘두른 60대, 징역형
# 5873  2022.06.17.  ‘스토킹 살해’ 김병찬 징역 35년… 모친 “예쁜 딸 안 돌아와” 오열
# 5874  2022.06.16.        “3살 아들 폭행 살해” 계모 징역 17년…친부도 법정 구속
#
#                                                                                 url  \
# 0                                 https://www.ytn.co.kr/_ln/0115_202201312029383965
# 1        http://www.newsis.com/view/?id=NISX20220131_0001743534&cID=10812&pID=10800
# 2      http://news.kmib.co.kr/article/view.asp?arcid=0016723451&code=61111111&cp=nv
# 3                                            https://www.news1.kr/articles/?4570950
# 4                                            https://www.news1.kr/articles/?4570040
# ...                                                                             ...
# 5870                                       https://www.nocutnews.co.kr/news/5771678
# 5871                    http://www.kyeongin.com/main/view.php?key=20220625010004576
# 5872     http://www.newsis.com/view/?id=NISX20220620_0001912948&cID=10810&pID=10800
# 5873  https://news.kmib.co.kr/article/view.asp?arcid=0924250762&code=11131200&cp=nv
# 5874                          https://news.kbs.co.kr/news/view.do?ncd=5488104&ref=A
#
#       index                              index_similarity  \
# 0        0$                 0$'제2의 자두 사건'...고양이 살해범 잡아주세요
# 1        1$              1$"고양이 꼬리잡고 바닥에 내리쳐 살해"…경찰 수사 착수
# 2        2$             2$이재명, 고양이 ‘두부’ 잔혹 살해에 “사람 향할 수도”
# 3        3$      3$[사건의 재구성]범행 감추려고 피해자 언니까지 살해한 인면수심 30대
# 4        4$       4$[사건의 재구성] 16살 연하 남친 살해한 돌싱녀…"내가 창피해?"
# ...     ...                                           ...
# 5870  8595$         8595$"모친 앞서 딸 살해…피해자 모친 정신적 피해도 심리돼야"
# 5871  8596$        8596$'발달장애 자녀 살해' 친모들… 같은 죄, 다른 벌 이유는?
# 5872  8597$      8597$술취해 12년 사실혼 끝에 헤어지자 흉기 휘두른 60대, 징역형
# 5873  8598$  8598$‘스토킹 살해’ 김병찬 징역 35년… 모친 “예쁜 딸 안 돌아와” 오열
# 5874  8599$        8599$“3살 아들 폭행 살해” 계모 징역 17년…친부도 법정 구속
#
#            title_similar_index      징역                     nouns   age
# 0                           []                      자두 사건 고양이 살해   NaN
# 1                           []          고양이 꼬리 잡고 바닥 살해 경찰 수사 착수   NaN
# 2                           []            이재명 고양이 두부 잔혹 살해 사람 수도   NaN
# 3                           []            사건 구성 범행 피해자 언니 살해 인면수    30
# 4                           []             사건 구성 연하 남친 살해 돌싱 창피해  None
# ...                        ...     ...                       ...   ...
# 5870  [[8995], [8895], [8795]]          모친 앞서 살해 피해자 모친 정신 피해 심리  None
# 5871  [[8996], [8896], [8796]]               발달장애 자녀 살해 친모 다른 이유  None
# 5872  [[8997], [8897], [8797]]               술취해 사실혼 헤어지자 흉기 징역형    60
# 5873  [[8998], [8898], [8798]]  징역 35년       스토킹 살해 김병찬 징역 모친 오열  None
# 5874  [[8999], [8899], [8799]]  징역 17년   아들 폭행 살해 계모 징역 친부 법정 구속  None
#
# [5840 rows x 9 columns]

# %%
df.head(50)
# Out:
#            date                                         title  \
# 0   2022.01.31.                   '제2의 자두 사건'...고양이 살해범 잡아주세요
# 1   2022.01.31.                "고양이 꼬리잡고 바닥에 내리쳐 살해"…경찰 수사 착수
# 2   2022.01.31.               이재명, 고양이 ‘두부’ 잔혹 살해에 “사람 향할 수도”
# 3   2022.01.31.        [사건의 재구성]범행 감추려고 피해자 언니까지 살해한 인면수심 30대
# 4   2022.01.30.         [사건의 재구성] 16살 연하 남친 살해한 돌싱녀…"내가 창피해?"
# 5   2022.01.30.           고양이 ‘두부’ 잔혹 살해 범죄에 이재명 “경찰 적극 수사해야”
# 6   2022.01.26.                 16세 연하 남친 흉기 살해 30대 여성 징역 22년
# 7   2022.01.26.             결혼 1달 만에 아내 폭행·살해한 50대에 징역 30년 구형
# 8   2022.01.26.        “내 번호 왜 지워”… 남친 살해한 여성, 무기징역→징역 22년 감형
# 9   2022.01.30.           창원서 고양이 꼬리 잡고 살해…이재명 “경찰의 적극 수사 요청”
# 10  2022.01.28.                  수억원 횡령 들통 나자 점주 살해 직원…징역 13년
# 11  2022.01.28.         70대 마구 때린 190㎝ 20대男…"형 가볍다" 2심서 징역 늘어
# 12  2022.01.30.                이재명, 고양이 학대 살해에 "범죄전담팀 구성해 엄단"
# 13  2022.01.25.             당진 자매 살해범 항소심도 무기징역…유족 “사형 선고했어야”
# 14  2022.01.25.            퇴거 통보에 이웃 흉기 분풀이…50대 살해범 징역 15년 선고
# 15  2022.01.31.            계약금 문제로 흉기 휘두른 50대, 항소심서도 징역 1년6개월
# 16  2022.01.30.       DR콩고 군사법원, 유엔 전문가 납치·살해하고 참수한 51명에 “사형”
# 17  2022.01.26.              “집착 성향 지속”…‘장검’ 부인 살해에 ‘무기징역’ 구형
# 18  2022.01.24.            무릎까지 꿇더니…'세모녀 살해' 김태현, 무기징역에 대법 상고
# 19  2022.01.29.                자해하고 6살 아들 살해 시도한 40대 친모, 집행유예
# 20  2022.01.25.                '자매 살해' 2심도 무기징역…사형 외쳤던 아버지 오열
# 21  2022.01.19.            '세모녀 살해' 2심…무기징역 선고하며 "가석방 안돼"(종합)
# 22  2022.01.29.  [단독] "소파에 소변보며 술주정"…벽돌로 남편 살해한 부인, 2심도 징역 4년
# 23  2022.01.19.            갓 태어난 영아 살해 방조한 30대 남성 2명, 각 징역 3년
# 24  2022.01.25.             당진 자매 살해범 항소심도 무기징역…유족 "어처구니가 없다"
# 25  2022.01.26.      '세 모녀 살해' 혐의 김태현 무기징역에 검찰도 상고… 대법원 최종 판단
# 26  2022.01.27.  '3세 딸 방치·사망' 30대 미혼모, 2심서 징역 15년..."지능지수 낮아"
# 27  2022.01.24.            수익금 안 주자 동업자 살해 시도…1명 징역4년, 2명은 집유
# 28  2022.01.20.                친할머니 살해한 10대 징역형…범행 방조한 동생은 집유
# 29  2022.01.29.              술 마시다 흉기 휘두른 70대 징역 6년…"심신미약 아냐"
# 30  2022.01.25.                   '사형 구형' 당진 자매 살해범 항소심 오늘 선고
# 31  2022.01.27.          6년간 스포츠용품 빼돌리다 발각돼 사장 살해한 40대 징역 13년
# 32  2022.01.30.              "反그리스도 머리 자르겠다" 미군 출신, 바이든 살해 위협
# 33  2022.01.30.       신생아 음식물 쓰레기통에 유기해 살해하려한 친모 징역 12년…불복 항소
# 34  2022.01.25.               대전고법, '당진 자매 살인' 30대 피고 무기징역 선고
# 35  2022.01.29.          넷플릭스 다큐 '타이거킹' 주인공, 청부살인 음모로 21년 징역형
# 36  2022.01.29.       눈 마주쳤다며 70대 무참히 폭행한 20대…항소심서 징역 4년으로 늘어
# 37  2022.01.21.             친모 꾸중에 흉기 휘둘러 살해한 30대… 2심서 징역 15년
# 38  2022.01.29.          술주정·폭언·욕설 시달려 남편 살해한 60대 아내, '징역 4년'
# 39  2022.01.20.              키워준 친할머니 살해한 10대 형제에 판사가 건넨 '선물'
# 40  2022.01.27.           3살 딸 방치해 숨지게 한 친모 2심서 감형…징역 20년→15년
# 41  2022.01.25.                 '친할머니 살해' 10대 징역 12년‥책 건넨 재판장
# 42  2022.01.25.              '반성문 16번' 제출했던 친할머니 살해 10대, 항소했다
# 43  2022.01.26.              동거녀 흉기로 잔혹 살해한 60대 남성 2심도 '무기징역'
# 44  2022.01.27.         “내 번호 지워?” 남친 34차례 찔러 살해한 30대 감형… 이유는
# 45  2022.01.28.                  '횡령 들키자 점주 살해' 40대 직원 징역 13년
# 46  2022.01.21.      [Pick] "범행 잔혹"…'친모 살해' 명문대 졸업생, 형량 더 늘었다
# 47  2022.01.20.             잔소리하는 할머니 살해 혐의 10대형제 兄 중형, 동생 집유
# 48  2022.01.19.      '세모녀 살해' 김태현 2심도 무기징역…법원 "가석방 허용 안돼"(종합)
# 49  2022.01.13.          '정인이법' 첫 적용, 10대 딸 '학대살해' 계모에 징역 30년
#
#                                                                                                                                     url  \
# 0                                                                                     https://www.ytn.co.kr/_ln/0115_202201312029383965
# 1                                                            http://www.newsis.com/view/?id=NISX20220131_0001743534&cID=10812&pID=10800
# 2                                                          http://news.kmib.co.kr/article/view.asp?arcid=0016723451&code=61111111&cp=nv
# 3                                                                                                https://www.news1.kr/articles/?4570950
# 4                                                                                                https://www.news1.kr/articles/?4570040
# 5                                                                    https://www.hani.co.kr/arti/politics/politics_general/1029321.html
# 6                                                           https://www.seoul.co.kr/news/newsView.php?id=20220126500100&wlog_tag3=naver
# 7                                                            http://www.newsis.com/view/?id=NISX20220126_0001738203&cID=10807&pID=10800
# 8   https://biz.chosun.com/topics/law_firm/2022/01/26/CICTF4BSGBGEVFNH2M2SFIA7ZI/?utm_source=naver&utm_medium=original&utm_campaign=biz
# 9                                                         http://www.segye.com/content/html/2022/01/30/20220130506469.html?OutUrl=naver
# 10                                                                                        http://www.fnnews.com/news/202201281044280038
# 11                                                           http://www.newsis.com/view/?id=NISX20220128_0001741876&cID=10201&pID=10200
# 12                                                           http://www.newsis.com/view/?id=NISX20220130_0001743065&cID=10301&pID=10300
# 13                                                                                https://news.kbs.co.kr/news/view.do?ncd=5381164&ref=A
# 14                                                           http://www.newsis.com/view/?id=NISX20220125_0001737143&cID=10201&pID=10200
# 15                                                                                         http://yna.kr/AKR20220128111500055?did=1195m
# 16                                                          https://www.seoul.co.kr/news/newsView.php?id=20220130500059&wlog_tag3=naver
# 17                                                          https://www.seoul.co.kr/news/newsView.php?id=20220126500144&wlog_tag3=naver
# 18                                                                                          https://www.joongang.co.kr/article/25043100
# 19                                                           http://www.newsis.com/view/?id=NISX20220128_0001742149&cID=10807&pID=10800
# 20                                                                  https://news.jtbc.joins.com/article/article.aspx?news_id=NB12044331
# 21                                                           http://www.newsis.com/view/?id=NISX20220119_0001730171&cID=10201&pID=10200
# 22                                                                                       http://news.tf.co.kr/read/national/1915813.htm
# 23                                                           http://www.newsis.com/view/?id=NISX20220119_0001730444&cID=10807&pID=10800
# 24                                                                                 http://news.mk.co.kr/newsRead.php?no=75711&year=2022
# 25                                                                        http://moneys.mt.co.kr/news/mwView.php?no=2022012618098013642
# 26                                                           http://www.newsis.com/view/?id=NISX20220127_0001739441&cID=10201&pID=10200
# 27                                                                                               https://www.news1.kr/articles/?4563390
# 28                                                                                             https://www.nocutnews.co.kr/news/5693406
# 29                                                                                         http://yna.kr/AKR20220128114800051?did=1195m
# 30                                                                                         http://yna.kr/AKR20220124153000063?did=1195m
# 31                                                                                               https://www.news1.kr/articles/?4568965
# 32                                                                                          https://www.joongang.co.kr/article/25044691
# 33                                                                                 https://www.inews365.com/news/article.html?no=700964
# 34                                                           http://www.newsis.com/view/?id=NISX20220125_0001736852&cID=10807&pID=10800
# 35                                                                                         http://yna.kr/AKR20220129019700075?did=1195m
# 36                                                        http://www.segye.com/content/html/2022/01/28/20220128512189.html?OutUrl=naver
# 37                                                        http://www.segye.com/content/html/2022/01/21/20220121505870.html?OutUrl=naver
# 38                                                                                               https://www.news1.kr/articles/?4570429
# 39                                                                   http://www.edaily.co.kr/news/newspath.asp?newsid=03732646632199688
# 40                                                                                         http://yna.kr/AKR20220127093000004?did=1195m
# 41                                                               https://imnews.imbc.com/replay/2022/nwtoday/article/6335776_35752.html
# 42                                                                        https://hankookilbo.com/News/Read/A2022012516590003163?did=NA
# 43                                                                                             https://www.nocutnews.co.kr/news/5696634
# 44                                                        http://www.segye.com/content/html/2022/01/27/20220127511412.html?OutUrl=naver
# 45                                                                                    https://www.ytn.co.kr/_ln/0103_202201280804077030
# 46                                                    https://news.sbs.co.kr/news/endPage.do?news_id=N1006613892&plink=ORI&cooper=NAVER
# 47                                                           http://www.newsis.com/view/?id=NISX20220120_0001730978&cID=10810&pID=10800
# 48                                                                                         http://yna.kr/AKR20220119116401004?did=1195m
# 49                                                           http://www.newsis.com/view/?id=NISX20220113_0001723163&cID=10812&pID=10800
#
#    index                                 index_similarity title_similar_index  \
# 0     0$                    0$'제2의 자두 사건'...고양이 살해범 잡아주세요                  []
# 1     1$                 1$"고양이 꼬리잡고 바닥에 내리쳐 살해"…경찰 수사 착수                  []
# 2     2$                2$이재명, 고양이 ‘두부’ 잔혹 살해에 “사람 향할 수도”                  []
# 3     3$         3$[사건의 재구성]범행 감추려고 피해자 언니까지 살해한 인면수심 30대                  []
# 4     4$          4$[사건의 재구성] 16살 연하 남친 살해한 돌싱녀…"내가 창피해?"                  []
# 5     5$            5$고양이 ‘두부’ 잔혹 살해 범죄에 이재명 “경찰 적극 수사해야”                  []
# 6     6$                  6$16세 연하 남친 흉기 살해 30대 여성 징역 22년                  []
# 7     9$              9$결혼 1달 만에 아내 폭행·살해한 50대에 징역 30년 구형                  []
# 8    10$        10$“내 번호 왜 지워”… 남친 살해한 여성, 무기징역→징역 22년 감형                  []
# 9    11$           11$창원서 고양이 꼬리 잡고 살해…이재명 “경찰의 적극 수사 요청”                  []
# 10   12$                  12$수억원 횡령 들통 나자 점주 살해 직원…징역 13년                  []
# 11   13$         13$70대 마구 때린 190㎝ 20대男…"형 가볍다" 2심서 징역 늘어                  []
# 12   14$                14$이재명, 고양이 학대 살해에 "범죄전담팀 구성해 엄단"                  []
# 13   15$             15$당진 자매 살해범 항소심도 무기징역…유족 “사형 선고했어야”                  []
# 14   16$            16$퇴거 통보에 이웃 흉기 분풀이…50대 살해범 징역 15년 선고                  []
# 15   17$            17$계약금 문제로 흉기 휘두른 50대, 항소심서도 징역 1년6개월                  []
# 16   18$       18$DR콩고 군사법원, 유엔 전문가 납치·살해하고 참수한 51명에 “사형”                  []
# 17   19$              19$“집착 성향 지속”…‘장검’ 부인 살해에 ‘무기징역’ 구형                  []
# 18   20$            20$무릎까지 꿇더니…'세모녀 살해' 김태현, 무기징역에 대법 상고                  []
# 19   22$                22$자해하고 6살 아들 살해 시도한 40대 친모, 집행유예                  []
# 20   23$                23$'자매 살해' 2심도 무기징역…사형 외쳤던 아버지 오열                  []
# 21   24$            24$'세모녀 살해' 2심…무기징역 선고하며 "가석방 안돼"(종합)                  []
# 22   28$  28$[단독] "소파에 소변보며 술주정"…벽돌로 남편 살해한 부인, 2심도 징역 4년                  []
# 23   29$            29$갓 태어난 영아 살해 방조한 30대 남성 2명, 각 징역 3년                  []
# 24   30$             30$당진 자매 살해범 항소심도 무기징역…유족 "어처구니가 없다"                  []
# 25   31$      31$'세 모녀 살해' 혐의 김태현 무기징역에 검찰도 상고… 대법원 최종 판단                  []
# 26   32$  32$'3세 딸 방치·사망' 30대 미혼모, 2심서 징역 15년..."지능지수 낮아"                  []
# 27   33$            33$수익금 안 주자 동업자 살해 시도…1명 징역4년, 2명은 집유                  []
# 28   34$                34$친할머니 살해한 10대 징역형…범행 방조한 동생은 집유                  []
# 29   36$              36$술 마시다 흉기 휘두른 70대 징역 6년…"심신미약 아냐"                  []
# 30   37$                   37$'사형 구형' 당진 자매 살해범 항소심 오늘 선고                  []
# 31   38$          38$6년간 스포츠용품 빼돌리다 발각돼 사장 살해한 40대 징역 13년                  []
# 32   39$              39$"反그리스도 머리 자르겠다" 미군 출신, 바이든 살해 위협                  []
# 33   41$       41$신생아 음식물 쓰레기통에 유기해 살해하려한 친모 징역 12년…불복 항소                  []
# 34   42$               42$대전고법, '당진 자매 살인' 30대 피고 무기징역 선고                  []
# 35   43$          43$넷플릭스 다큐 '타이거킹' 주인공, 청부살인 음모로 21년 징역형                  []
# 36   44$       44$눈 마주쳤다며 70대 무참히 폭행한 20대…항소심서 징역 4년으로 늘어                  []
# 37   45$             45$친모 꾸중에 흉기 휘둘러 살해한 30대… 2심서 징역 15년                  []
# 38   46$          46$술주정·폭언·욕설 시달려 남편 살해한 60대 아내, '징역 4년'                  []
# 39   47$              47$키워준 친할머니 살해한 10대 형제에 판사가 건넨 '선물'                  []
# 40   48$           48$3살 딸 방치해 숨지게 한 친모 2심서 감형…징역 20년→15년                  []
# 41   50$                 50$'친할머니 살해' 10대 징역 12년‥책 건넨 재판장                  []
# 42   51$              51$'반성문 16번' 제출했던 친할머니 살해 10대, 항소했다                  []
# 43   53$              53$동거녀 흉기로 잔혹 살해한 60대 남성 2심도 '무기징역'                  []
# 44   54$         54$“내 번호 지워?” 남친 34차례 찔러 살해한 30대 감형… 이유는                  []
# 45   55$                  55$'횡령 들키자 점주 살해' 40대 직원 징역 13년                  []
# 46   56$      56$[Pick] "범행 잔혹"…'친모 살해' 명문대 졸업생, 형량 더 늘었다                  []
# 47   57$             57$잔소리하는 할머니 살해 혐의 10대형제 兄 중형, 동생 집유                  []
# 48   58$      58$'세모녀 살해' 김태현 2심도 무기징역…법원 "가석방 허용 안돼"(종합)                  []
# 49   59$          59$'정인이법' 첫 적용, 10대 딸 '학대살해' 계모에 징역 30년                  []
#
#              징역                              nouns   age
# 0                                     자두 사건 고양이 살해   NaN
# 1                         고양이 꼬리 잡고 바닥 살해 경찰 수사 착수   NaN
# 2                           이재명 고양이 두부 잔혹 살해 사람 수도   NaN
# 3                           사건 구성 범행 피해자 언니 살해 인면수    30
# 4                            사건 구성 연하 남친 살해 돌싱 창피해  None
# 5                     고양이 두부 잔혹 살해 범죄 이재명 경찰 적극 수사  None
# 6        징역 22년                  연하 남친 흉기 살해 여성 징역    30
# 7        징역 30년                  결혼 아내 폭행 살해 징역 구형    50
# 8   무기징역 징역 22년             번호 남친 살해 여성 무기징역 징역 감형  None
# 9                  창원 고양이 꼬리 잡고 살해 이재명 경찰 적극 수사 요청  None
# 10       징역 13년               억원 횡령 들통 점주 살해 직원 징역  None
# 11                                           마구 징역    20
# 12                       이재명 고양이 학대 살해 범죄 전담 구성 엄단  None
# 13     무기징역 사형          당진 자매 살해 항소심 무기징역 유족 사형 선고  None
# 14       징역 15년           퇴거 통보 이웃 흉기 분풀이 살해 징역 선고    50
# 15        징역 1년             계약금 문제 흉기 항소심 서도 징역 개월    50
# 16          사형          콩고 군사법원 유엔 전문가 납치 살해 참수 사형  None
# 17         무기징역          집착 성향 지속 장검 부인 살해 무기징역 구형  None
# 18         무기징역            무릎 모녀 살해 김태현 무기징역 대법 상고  None
# 19                             자해 아들 살해 시도 친모 집행유예    40
# 20     무기징역 사형                자매 살해 무기징역 사형 아버지 오열  None
# 21         무기징역               모녀 살해 무기징역 선고 가석방 종합  None
# 22        징역 4년         단독 소파 소변 주정 벽돌 남편 살해 부인 징역  None
# 23        징역 3년                     영아 살해 방조 남성 징역    30
# 24         무기징역          당진 자매 살해 항소심 무기징역 유족 어처구니  None
# 25         무기징역  모녀 살해 혐의 김태현 무기징역 검찰 상고 대법원 최종 판단  None
# 26       징역 15년                  방치 사망 미혼모 징역 지능지수    30
# 27         징역4년              수익금 주자 업자 살해 시도 징역 집유  None
# 28         징역형              할머니 살해 징역형 범행 방조 동생 집유    10
# 29        징역 6년                        흉기 징역 심신 미약    70
# 30      사형  구형            사형 구형 당진 자매 살해 항소심 오늘 선고  None
# 31       징역 13년                 스포츠 용품 발각 사장 살해 징역    40
# 32                         그리스도 머리 미군 출신 바이든 살해 위협  None
# 33       징역 12년     신생아 음식물 쓰레기통 유기 살해 친모 징역 불복 항소  None
# 34         무기징역          대전 고법 당진 자매 살인 피고 무기징역 선고    30
# 35                    넷플릭스 다큐 타이거 주인공 청부 살인 음모 징역형  None
# 36        징역 4년                       무참 폭행 항소심 징역    20
# 37       징역 15년                     친모 꾸중 흉기 살해 징역    30
# 38        징역 4년               주정 폭언 욕설 남편 살해 아내 징역    60
# 39                                 할머니 살해 형제 판사 선물    10
# 40   감형  징역 20년                        방치 친모 감형 징역  None
# 41       징역 12년                       할머니 살해 징역 재판    10
# 42                                 성문 제출 할머니 살해 항소    10
# 43         무기징역                동거 흉기 잔혹 살해 남성 무기징역    60
# 44          감형                   번호 남친 차례 살해 감형 이유    30
# 45       징역 13년                     횡령 점주 살해 직원 징역    40
# 46                           범행 잔혹 친모 살해 명문 졸업생 형량  None
# 47          중형           잔소리 할머니 살해 혐의 형제 중형 동생 집유    10
# 48         무기징역        모녀 살해 김태현 무기징역 법원 가석방 허용 종합  None
# 49       징역 30년               정인 이법 적용 학대 살해 계모 징역    10

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head(20)
# Out:
#            date                                    title  \
# 0   2022.01.31.              '제2의 자두 사건'...고양이 살해범 잡아주세요
# 1   2022.01.31.           "고양이 꼬리잡고 바닥에 내리쳐 살해"…경찰 수사 착수
# 2   2022.01.31.          이재명, 고양이 ‘두부’ 잔혹 살해에 “사람 향할 수도”
# 3   2022.01.31.   [사건의 재구성]범행 감추려고 피해자 언니까지 살해한 인면수심 30대
# 4   2022.01.30.    [사건의 재구성] 16살 연하 남친 살해한 돌싱녀…"내가 창피해?"
# 5   2022.01.30.      고양이 ‘두부’ 잔혹 살해 범죄에 이재명 “경찰 적극 수사해야”
# 6   2022.01.26.            16세 연하 남친 흉기 살해 30대 여성 징역 22년
# 7   2022.01.26.        결혼 1달 만에 아내 폭행·살해한 50대에 징역 30년 구형
# 8   2022.01.26.   “내 번호 왜 지워”… 남친 살해한 여성, 무기징역→징역 22년 감형
# 9   2022.01.30.      창원서 고양이 꼬리 잡고 살해…이재명 “경찰의 적극 수사 요청”
# 10  2022.01.28.             수억원 횡령 들통 나자 점주 살해 직원…징역 13년
# 11  2022.01.28.    70대 마구 때린 190㎝ 20대男…"형 가볍다" 2심서 징역 늘어
# 12  2022.01.30.           이재명, 고양이 학대 살해에 "범죄전담팀 구성해 엄단"
# 13  2022.01.25.        당진 자매 살해범 항소심도 무기징역…유족 “사형 선고했어야”
# 14  2022.01.25.       퇴거 통보에 이웃 흉기 분풀이…50대 살해범 징역 15년 선고
# 15  2022.01.31.       계약금 문제로 흉기 휘두른 50대, 항소심서도 징역 1년6개월
# 16  2022.01.30.  DR콩고 군사법원, 유엔 전문가 납치·살해하고 참수한 51명에 “사형”
# 17  2022.01.26.         “집착 성향 지속”…‘장검’ 부인 살해에 ‘무기징역’ 구형
# 18  2022.01.24.       무릎까지 꿇더니…'세모녀 살해' 김태현, 무기징역에 대법 상고
# 19  2022.01.29.           자해하고 6살 아들 살해 시도한 40대 친모, 집행유예
#
#                                                                                                                                     url  \
# 0                                                                                     https://www.ytn.co.kr/_ln/0115_202201312029383965
# 1                                                            http://www.newsis.com/view/?id=NISX20220131_0001743534&cID=10812&pID=10800
# 2                                                          http://news.kmib.co.kr/article/view.asp?arcid=0016723451&code=61111111&cp=nv
# 3                                                                                                https://www.news1.kr/articles/?4570950
# 4                                                                                                https://www.news1.kr/articles/?4570040
# 5                                                                    https://www.hani.co.kr/arti/politics/politics_general/1029321.html
# 6                                                           https://www.seoul.co.kr/news/newsView.php?id=20220126500100&wlog_tag3=naver
# 7                                                            http://www.newsis.com/view/?id=NISX20220126_0001738203&cID=10807&pID=10800
# 8   https://biz.chosun.com/topics/law_firm/2022/01/26/CICTF4BSGBGEVFNH2M2SFIA7ZI/?utm_source=naver&utm_medium=original&utm_campaign=biz
# 9                                                         http://www.segye.com/content/html/2022/01/30/20220130506469.html?OutUrl=naver
# 10                                                                                        http://www.fnnews.com/news/202201281044280038
# 11                                                           http://www.newsis.com/view/?id=NISX20220128_0001741876&cID=10201&pID=10200
# 12                                                           http://www.newsis.com/view/?id=NISX20220130_0001743065&cID=10301&pID=10300
# 13                                                                                https://news.kbs.co.kr/news/view.do?ncd=5381164&ref=A
# 14                                                           http://www.newsis.com/view/?id=NISX20220125_0001737143&cID=10201&pID=10200
# 15                                                                                         http://yna.kr/AKR20220128111500055?did=1195m
# 16                                                          https://www.seoul.co.kr/news/newsView.php?id=20220130500059&wlog_tag3=naver
# 17                                                          https://www.seoul.co.kr/news/newsView.php?id=20220126500144&wlog_tag3=naver
# 18                                                                                          https://www.joongang.co.kr/article/25043100
# 19                                                           http://www.newsis.com/view/?id=NISX20220128_0001742149&cID=10807&pID=10800
#
#    index                            index_similarity title_similar_index  \
# 0     0$               0$'제2의 자두 사건'...고양이 살해범 잡아주세요                  []
# 1     1$            1$"고양이 꼬리잡고 바닥에 내리쳐 살해"…경찰 수사 착수                  []
# 2     2$           2$이재명, 고양이 ‘두부’ 잔혹 살해에 “사람 향할 수도”                  []
# 3     3$    3$[사건의 재구성]범행 감추려고 피해자 언니까지 살해한 인면수심 30대                  []
# 4     4$     4$[사건의 재구성] 16살 연하 남친 살해한 돌싱녀…"내가 창피해?"                  []
# 5     5$       5$고양이 ‘두부’ 잔혹 살해 범죄에 이재명 “경찰 적극 수사해야”                  []
# 6     6$             6$16세 연하 남친 흉기 살해 30대 여성 징역 22년                  []
# 7     9$         9$결혼 1달 만에 아내 폭행·살해한 50대에 징역 30년 구형                  []
# 8    10$   10$“내 번호 왜 지워”… 남친 살해한 여성, 무기징역→징역 22년 감형                  []
# 9    11$      11$창원서 고양이 꼬리 잡고 살해…이재명 “경찰의 적극 수사 요청”                  []
# 10   12$             12$수억원 횡령 들통 나자 점주 살해 직원…징역 13년                  []
# 11   13$    13$70대 마구 때린 190㎝ 20대男…"형 가볍다" 2심서 징역 늘어                  []
# 12   14$           14$이재명, 고양이 학대 살해에 "범죄전담팀 구성해 엄단"                  []
# 13   15$        15$당진 자매 살해범 항소심도 무기징역…유족 “사형 선고했어야”                  []
# 14   16$       16$퇴거 통보에 이웃 흉기 분풀이…50대 살해범 징역 15년 선고                  []
# 15   17$       17$계약금 문제로 흉기 휘두른 50대, 항소심서도 징역 1년6개월                  []
# 16   18$  18$DR콩고 군사법원, 유엔 전문가 납치·살해하고 참수한 51명에 “사형”                  []
# 17   19$         19$“집착 성향 지속”…‘장검’ 부인 살해에 ‘무기징역’ 구형                  []
# 18   20$       20$무릎까지 꿇더니…'세모녀 살해' 김태현, 무기징역에 대법 상고                  []
# 19   22$           22$자해하고 6살 아들 살해 시도한 40대 친모, 집행유예                  []
#
#              징역                            nouns   age
# 0                                   자두 사건 고양이 살해   NaN
# 1                       고양이 꼬리 잡고 바닥 살해 경찰 수사 착수   NaN
# 2                         이재명 고양이 두부 잔혹 살해 사람 수도   NaN
# 3                         사건 구성 범행 피해자 언니 살해 인면수    30
# 4                          사건 구성 연하 남친 살해 돌싱 창피해  None
# 5                   고양이 두부 잔혹 살해 범죄 이재명 경찰 적극 수사  None
# 6        징역 22년                연하 남친 흉기 살해 여성 징역    30
# 7        징역 30년                결혼 아내 폭행 살해 징역 구형    50
# 8   무기징역 징역 22년           번호 남친 살해 여성 무기징역 징역 감형  None
# 9                창원 고양이 꼬리 잡고 살해 이재명 경찰 적극 수사 요청  None
# 10       징역 13년             억원 횡령 들통 점주 살해 직원 징역  None
# 11                                         마구 징역    20
# 12                     이재명 고양이 학대 살해 범죄 전담 구성 엄단  None
# 13     무기징역 사형        당진 자매 살해 항소심 무기징역 유족 사형 선고  None
# 14       징역 15년         퇴거 통보 이웃 흉기 분풀이 살해 징역 선고    50
# 15        징역 1년           계약금 문제 흉기 항소심 서도 징역 개월    50
# 16          사형        콩고 군사법원 유엔 전문가 납치 살해 참수 사형  None
# 17         무기징역        집착 성향 지속 장검 부인 살해 무기징역 구형  None
# 18         무기징역          무릎 모녀 살해 김태현 무기징역 대법 상고  None
# 19                           자해 아들 살해 시도 친모 집행유예    40

# %% [markdown]
# ## 뉴스 기사 분석 토대로 만든 살인 범죄 사전 (+유사단어 및 통계에서 얻은 키워드 추가)

# %%
crime_dict = pd.read_csv('./범죄_사전.csv', encoding='utf-8')
crime_dict.head()
# Out:
#   person method reason
# 0     아내     흉기    생활고
# 1   남자친구     둔기    잔소리
# 2     아들    성폭행      빚
# 3     여친    성추행     장애
# 4     부부     폭행     복수

# %% [markdown]
# ## 7. 피해자

# %%
for i in range(len(df)): # df 의 행 수만큼 for 문 돌린다.
    victim = df.loc[i,'nouns'] # 컬럼만의 각 값을 순서대로 가져온다.
    victim = list(victim.split())
    
    temp_li = []
    if '살해' in victim:
        index = victim.index('살해') #살해 라는 단어 전 단어들만 추출
        victim = victim[:index]

        if len(victim) > 0:

            for v in victim:
                v = list(v.split())
                for j in v:
                    if j in list(crime_dict['person']):
                        temp_li.append(j)
                    
                            
    
    
    if len(temp_li) > 0:
        print(temp_li)
        temp_li = temp_li[-1] #여러개 나올 경우 살해 바로 전 사람단어로 선택
        df.loc[i,'victim']= temp_li
        
    else:
        
        df.loc[i,'victim']= None
# Out:
# ['피해자', '언니']
# ['아내']
# ['자매']
# ['이웃']
# ['아들']
# ['자매']
# ['남편']
# ['자매']
# ['자매']
# ['남편']
# ['동거']
# ['여자친구']
# ['여친']
# ['고교생']
# ['자매']
# ['지인', '여성']
# ['자매']
# ['자매']
# ['남자친구']
# ['자녀']
# ['아내']
# ['아내']
# ['아내']
# ['자매']
# ['아들']
# ['친구']
# ['아내']
# ['여자친구', '언니']
# ['친구']
# ['이웃']
# ['남자친구']
# ['자매']
# ['자매']
# ['이웃']
# ['친구']
# ['여자친구', '언니']
# ['자매']
# ['모친']
# ['아내']
# ['친구']
# ['아내']
# ['남자친구']
# ['자매']
# ['자매']
# ['이웃']
# ['아내']
# ['아내']
# ['친구']
# ['여자친구', '언니']
# ['연인']
# ['여친', '언니']
# ['지인']
# ['지인']
# ['자매']
# ['지인']
# ['남자친구']
# ['자매']
# ['자매']
# ['자매']
# ['자매']
# ['여자친구', '언니']
# ['고교생']
# ['형제']
# ['고교생']
# ['여성']
# ['지인']
# ['지인']
# ['아버지']
# ['아내']
# ['지인']
# ['아내']
# ['지인']
# ['아내']
# ['아내']
# ['아내']
# ['아내']
# ['아내']
# ['아버지']
# ['피해자']
# ['아내']
# ['동거']
# ['아내']
# ['여자친구']
# ['자녀', '아내']
# ['아들']
# ['아들', '아내']
# ['동거', '피해자']
# ['여친']
# ['동거']
# ['연인']
# ['부모']
# ['아내']
# ['누나']
# ['아내']
# ['애인']
# ['동거']
# ['아내']
# ['동생']
# ['친구']
# ['아내']
# ['아내']
# ['노모']
# ['여성']
# ['부모']
# ['아내']
# ['동거']
# ['친구']
# ['아내']
# ['노모']
# ['남편']
# ['아내']
# ['아내']
# ['지인']
# ['아버지']
# ['아내']
# ['동거']
# ['아내']
# ['아버지']
# ['아내']
# ['아내']
# ['아내']
# ['노모']
# ['아내']
# ['노모']
# ['아들']
# ['동거']
# ['여자친구']
# ['아내']
# ['아내']
# ['애인']
# ['아내']
# ['어머니', '부모']
# ['아내']
# ['아내']
# ['여친']
# ['아내', '아내']
# ['부부']
# ['아내']
# ['아들', '아내']
# ['노모']
# ['부모']
# ['아내']
# ['아들', '아내']
# ['노모']
# ['아내']
# ['아내']
# ['동거']
# ['아내']
# ['아내']
# ['아들']
# ['아내']
# ['부모']
# ['남편', '아내']
# ['아내']
# ['아내']
# ['부모']
# ['남편']
# ['부모']
# ['이웃']
# ['어머니']
# ['아내']
# ['아들', '아내']
# ['여친']
# ['동생']
# ['아내']
# ['친구']
# ['지인']
# ['노모']
# ['노모']
# ['배우자']
# ['아내']
# ['아내']
# ['아내']
# ['여친']
# ['아내']
# ['지인']
# ['아내']
# ['아내']
# ['여친']
# ['친구']
# ['부모']
# ['지인']
# ['여성']
# ['어머니']
# ['아내']
# ['애인']
# ['친구']
# ['친구']
# ['애인']
# ['노모']
# ['동생']
# ['주인']
# ['여친']
# ['아내']
# ['아내']
# ['지인']
# ['아내']
# ['동료']
# ['지인']
# ['주인']
# ['노모']
# ['노모']
# ['친구']
# ['부모']
# ['아내']
# ['부모']
# ['지인']
# ['지인']
# ['아버지']
# ['아내']
# ['지인']
# ['아내']
# ['지인']
# ['아내']
# ['아내']
# ['아내']
# ['아내']
# ['아내']
# ['아버지']
# ['피해자']
# ['아내']
# ['동거']
# ['아내']
# ['여자친구']
# ['자녀', '아내']
# ['아들']
# ['아들', '아내']
# ['동거', '피해자']
# ['여친']
# ['동거']
# ['연인']
# ['부모']
# ['아내']
# ['누나']
# ['아내']
# ['애인']
# ['동거']
# ['아내']
# ['동생']
# ['친구']
# ['아내']
# ['아내']
# ['노모']
# ['여성']
# ['부모']
# ['아내']
# ['동거']
# ['친구']
# ['아내']
# ['노모']
# ['남편']
# ['아내']
# ['아내']
# ['지인']
# ['아버지']
# ['아내']
# ['동거']
# ['아내']
# ['아버지']
# ['아내']
# ['아내']
# ['아내']
# ['노모']
# ['아내']
# ['노모']
# ['아들']
# ['동거']
# ['여자친구']
# ['아내']
# ['아내']
# ['애인']
# ['아내']
# ['어머니', '부모']
# ['아내']
# ['아내']
# ['여친']
# ['아내', '아내']
# ['부부']
# ['아내']
# ['아들', '아내']
# ['노모']
# ['부모']
# ['아내']
# ['아들', '아내']
# ['노모']
# ['아내']
# ['아내']
# ['동거']
# ['아내']
# ['아내']
# ['아들']
# ['아내']
# ['남편', '아내']
# ['아내']
# ['아내']
# ['부모']
# ['남편']
# ['부모']
# ['이웃']
# ['어머니']
# ['아내']
# ['아들', '아내']
# ['여친']
# ['동생']
# ['아내']
# ['친구']
# ['지인']
# ['노모']
# ['노모']
# ['배우자']
# ['아내']
# ['아내']
# ['아내']
# ['여친']
# ['아내']
# ['지인']
# ['아내']
# ['아내']
# ['여친']
# ['친구']
# ['부모']
# ['지인']
# ['여성']
# ['어머니']
# ['아내']
# ['애인']
# ['친구']
# ['친구']
# ['애인']
# ['노모']
# ['동생']
# ['주인']
# ['여친']
# ['아내']
# ['아내']
# ['지인']
# ['아내']
# ['동료']
# ['지인']
# ['주인']
# ['노모']
# ['노모']
# ['친구']
# ['부모']
# ['아내']
# ['부모']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['이웃']
# ['여성']
# ['여성']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['남편']
# ['여성']
# ['동거']
# ['여성']
# ['자녀']
# ['자녀']
# ['자녀']
# ['여성']
# ['동거']
# ['아내']
# ['여성']
# ['동거']
# ['여성']
# ['부모']
# ['사촌']
# ['직원']
# ['피해자']
# ['여친']
# ['여성']
# ['부모']
# ['동거']
# ['동료', '남편']
# ['여자친구']
# ['아들']
# ['여성']
# ['여친']
# ['여성']
# ['여성']
# ['여친']
# ['아들']
# ['주인']
# ['아들']
# ['아버지']
# ['여자친구']
# ['아내']
# ['누나', '동거']
# ['아내']
# ['아들']
# ['모친']
# ['자녀']
# ['아들']
# ['아들']
# ['주인']
# ['아들']
# ['아버지']
# ['여자친구']
# ['아내']
# ['누나', '동거']
# ['아내']
# ['아들']
# ['모친']
# ['자녀']
# ['아들']
# ['아들']
# ['아들']
# ['직원']
# ['아들']
# ['자녀']
# ['자녀']
# ['자녀']
# ['여성']
# ['동거']
# ['아내']
# ['여성']
# ['동거']
# ['여성']
# ['부모']
# ['사촌']
# ['직원']
# ['피해자']
# ['여친']
# ['여성']
# ['부모']
# ['동거']
# ['동료', '남편']
# ['여자친구']
# ['아들']
# ['여성']
# ['여친']
# ['여성']
# ['여성']
# ['여친']
# ['아들']
# ['주인']
# ['아들']
# ['아버지']
# ['여자친구']
# ['아내']
# ['누나', '동거']
# ['아내']
# ['아들']
# ['모친']
# ['자녀']
# ['아들']
# ['아들']
# ['아들']
# ['직원']
# ['아들']
# ['자녀']
# ['자녀']
# ['자녀']
# ['여성']
# ['동거']
# ['아내']
# ['여성']
# ['동거']
# ['여성']
# ['부모']
# ['사촌']
# ['직원']
# ['피해자']
# ['여친']
# ['여성']
# ['부모']
# ['동거']
# ['동료', '남편']
# ['여자친구']
# ['아들']
# ['여성']
# ['여친']
# ['여성']
# ['여성']
# ['여친']
# ['아들']
# ['주인']
# ['아들']
# ['아버지']
# ['여자친구']
# ['아내']
# ['누나', '동거']
# ['아내']
# ['아들']
# ['모친']
# ['자녀']
# ['아들']
# ['아들']
# ['아들']
# ['직원']
# ['아들']
# ['자녀']
# ['자녀']
# ['자녀']
# ['여성']
# ['동거']
# ['아내']
# ['여성']
# ['동거']
# ['여성']
# ['부모']
# ['사촌']
# ['직원']
# ['피해자']
# ['여친']
# ['여성']
# ['부모']
# ['동거']
# ['동료', '남편']
# ['여자친구']
# ['아들']
# ['여성']
# ['여친']
# ['여성']
# ['여성']
# ['여친']
# ['아들']
# ['주인']
# ['아들']
# ['아버지']
# ['여자친구']
# ['아내']
# ['누나', '동거']
# ['아내']
# ['아들']
# ['모친']
# ['자녀']
# ['아들']
# ['아들']
# ['아들']
# ['직원']
# ['아들']
# ['자녀']
# ['자녀']
# ['자녀']
# ['여성']
# ['동거']
# ['아내']
# ['여성']
# ['동거']
# ['여성']
# ['부모']
# ['사촌']
# ['직원']
# ['피해자']
# ['여친']
# ['여성']
# ['부모']
# ['동거']
# ['동료', '남편']
# ['여자친구']
# ['아들']
# ['여성']
# ['여친']
# ['여성']
# ['여성']
# ['여친']
# ['아들']
# ['주인']
# ['아들']
# ['아버지']
# ['여자친구']
# ['아내']
# ['누나', '동거']
# ['아내']
# ['아들']
# ['모친']
# ['자녀']
# ['아들']
# ['아들']
# ['아들']
# ['직원']
# ['아들']
# ['자녀']
# ['자녀']
# ['자녀']
# ['여성']
# ['동거']
# ['아내']
# ['여성']
# ['동거']
# ['여성']
# ['부모']
# ['사촌']
# ['직원']
# ['피해자']
# ['여친']
# ['여성']
# ['부모']
# ['동거']
# ['동료', '남편']
# ['여자친구']
# ['아들']
# ['여성']
# ['여친']
# ['여성']
# ['여성']
# ['여친']
# ['아들']
# ['주인']
# ['아들']
# ['아버지']
# ['여자친구']
# ['아내']
# ['누나', '동거']
# ['아내']
# ['아들']
# ['모친']
# ['자녀']
# ['아들']

# %% [markdown]
# ## 8. 가해자

# %%
for i in range(len(df)): # df 의 행 수만큼 for 문 돌린다.
    victim = df.loc[i,'nouns'] # 컬럼만의 각 값을 순서대로 가져온다.
    victim = list(victim.split())
    
    temp_li = []
    if '살해' in victim:
        index = victim.index('살해') #살해 라는 단어 후 단어들만 추출
        victim = victim[(index+1):]

        if len(victim) > 0:

            for v in victim:
                v = list(v.split())
                for j in v:
                    if j in list(crime_dict['person']):
                        temp_li.append(j)
                    
                            
    
    
    if len(temp_li) > 0:
        print(temp_li)
        temp_li = temp_li[0] #여러개 나올 경우 살해 바로 후 사람단어로 선택
        df.loc[i,'murderer']= temp_li
        
    else:
        
        df.loc[i,'murderer']= None
# Out:
# ['여성']
# ['여성']
# ['직원']
# ['아버지']
# ['동생']
# ['아내']
# ['형제']
# ['직원']
# ['형제', '동생']
# ['동거']
# ['아버지']
# ['동거']
# ['형제']
# ['엄마']
# ['남편']
# ['형제']
# ['어머니']
# ['형제']
# ['여성']
# ['직원']
# ['형제', '동생']
# ['형제']
# ['여성']
# ['동생']
# ['형제']
# ['형제']
# ['동생']
# ['형제']
# ['자매']
# ['형제', '동생']
# ['형제']
# ['형제']
# ['형제']
# ['형제']
# ['여성']
# ['여친']
# ['동생']
# ['형제']
# ['형제']
# ['형제', '동생']
# ['동생', '형제']
# ['형제', '동생']
# ['형제', '동생']
# ['여성']
# ['남편']
# ['남편']
# ['피해자']
# ['계부']
# ['남편']
# ['아들']
# ['동생']
# ['남편']
# ['아들']
# ['부부']
# ['오빠']
# ['어머니']
# ['남편']
# ['여성']
# ['아들']
# ['아내']
# ['부부']
# ['여성']
# ['가해자']
# ['남편']
# ['부부']
# ['아내']
# ['아들']
# ['아들']
# ['부부']
# ['부부']
# ['남편']
# ['어머니']
# ['아들']
# ['아들', '어머니']
# ['남편']
# ['부부']
# ['아들']
# ['남편']
# ['부부']
# ['부부']
# ['남편']
# ['남편']
# ['어머니']
# ['아내']
# ['부부']
# ['아들']
# ['남편']
# ['아버지']
# ['여성']
# ['아들']
# ['아들']
# ['부부']
# ['아버지']
# ['남편']
# ['부부']
# ['어머니']
# ['친부']
# ['아들']
# ['직원']
# ['여성']
# ['아들']
# ['아버지']
# ['계부']
# ['여친', '엄마']
# ['누나']
# ['아들']
# ['이웃']
# ['남편']
# ['여성']
# ['가해자']
# ['여성']
# ['남편']
# ['남편']
# ['피해자']
# ['계부']
# ['남편']
# ['아들']
# ['동생']
# ['남편']
# ['아들']
# ['부부']
# ['오빠']
# ['어머니']
# ['남편']
# ['여성']
# ['아들']
# ['아내']
# ['부부']
# ['여성']
# ['가해자']
# ['남편']
# ['부부']
# ['아내']
# ['아들']
# ['아들']
# ['부부']
# ['부부']
# ['남편']
# ['어머니']
# ['아들']
# ['아들', '어머니']
# ['남편']
# ['부부']
# ['부부']
# ['아들']
# ['남편']
# ['부부']
# ['부부']
# ['남편']
# ['남편']
# ['어머니']
# ['아내']
# ['부부']
# ['아들']
# ['남편']
# ['아버지']
# ['여성']
# ['아들']
# ['아들']
# ['부부']
# ['아버지']
# ['남편']
# ['부부']
# ['어머니']
# ['친부']
# ['아들']
# ['직원']
# ['여성']
# ['아들']
# ['아버지']
# ['계부']
# ['여친', '엄마']
# ['누나']
# ['아들']
# ['이웃']
# ['남편']
# ['여성']
# ['가해자']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['이웃']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['여성']
# ['여성']
# ['엄마']
# ['여성']
# ['부모']
# ['자녀', '부모']
# ['엄마']
# ['계부']
# ['부모']
# ['여성']
# ['엄마']
# ['엄마']
# ['부모']
# ['주인']
# ['계부']
# ['아들']
# ['남편']
# ['피해자', '모친']
# ['모친']
# ['친부']
# ['계부']
# ['아들']
# ['남편']
# ['피해자', '모친']
# ['모친']
# ['친부']
# ['엄마']
# ['모친']
# ['부모']
# ['부모']
# ['자녀', '부모']
# ['엄마']
# ['계부']
# ['부모']
# ['여성']
# ['엄마']
# ['엄마']
# ['부모']
# ['주인']
# ['계부']
# ['아들']
# ['남편']
# ['피해자', '모친']
# ['모친']
# ['친부']
# ['엄마']
# ['모친']
# ['부모']
# ['부모']
# ['자녀', '부모']
# ['엄마']
# ['계부']
# ['부모']
# ['여성']
# ['엄마']
# ['엄마']
# ['부모']
# ['주인']
# ['계부']
# ['아들']
# ['남편']
# ['피해자', '모친']
# ['모친']
# ['친부']
# ['엄마']
# ['모친']
# ['부모']
# ['부모']
# ['자녀', '부모']
# ['엄마']
# ['계부']
# ['부모']
# ['여성']
# ['엄마']
# ['엄마']
# ['부모']
# ['주인']
# ['계부']
# ['아들']
# ['남편']
# ['피해자', '모친']
# ['모친']
# ['친부']
# ['엄마']
# ['모친']
# ['부모']
# ['부모']
# ['자녀', '부모']
# ['엄마']
# ['계부']
# ['부모']
# ['여성']
# ['엄마']
# ['엄마']
# ['부모']
# ['주인']
# ['계부']
# ['아들']
# ['남편']
# ['피해자', '모친']
# ['모친']
# ['친부']
# ['엄마']
# ['모친']
# ['부모']
# ['부모']
# ['자녀', '부모']
# ['엄마']
# ['계부']
# ['부모']
# ['여성']
# ['엄마']
# ['엄마']
# ['부모']
# ['주인']
# ['계부']
# ['아들']
# ['남편']
# ['피해자', '모친']
# ['모친']
# ['친부']

# %% [markdown]
# ## 9. 피해자와 가해자 둘중 하나가 None일 경우 관계를 파악

# %%
import re

for i in range(len(df)): # df 의 행 수만큼 for 문 돌린다.
    victim = df.loc[i,'victim']
    
    
    if df.loc[i,'murderer'] == None: # 비어있을 경우에만 
        if victim == '아내':
            df.loc[i,'murderer'] = '남편'

        if victim == '배우자':
            df.loc[i,'murderer'] = '배우자'

        if victim == '친구':
            df.loc[i,'murderer'] = '친구'

        if victim == '부모':
            df.loc[i,'murderer'] = '자식'

        if victim == '지인':
            df.loc[i,'murderer'] = '지인'

# %%
import re

for i in range(len(df)): # df 의 행 수만큼 for 문 돌린다.
    murderer = df.loc[i,'murderer']
    
    
    if df.loc[i,'victim'] == None: # 비어있을 경우에만 
        if murderer == '아내':
            df.loc[i,'victim'] = '남편'

        if murderer == '배우자':
            df.loc[i,'victim'] = '배우자'

        if murderer == '친구':
            df.loc[i,'victim'] = '친구'

        if murderer == '부모':
            df.loc[i,'victim'] = '자식'

        if murderer == '지인':
            df.loc[i,'victim'] = '지인'
            
        if murderer == '자식':
            df.loc[i,'victim'] = '부모'
            
        if murderer == '아버지' or murderer == '어머니':
            df.loc[i,'victim'] = '자녀'

# %% [markdown]
# ## 10 . 결과

# %%
preprocessed_df = df[df[['title','url','징역','age','victim','murderer']].notna().all(axis=1)]

# %%
preprocessed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 605 entries, 7 to 5821
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      605 non-null    object
#  1   title     605 non-null    object
#  2   url       605 non-null    object
#  3   징역        605 non-null    object
#  4   nouns     605 non-null    object
#  5   age       605 non-null    object
#  6   victim    605 non-null    object
#  7   murderer  605 non-null    object
# dtypes: object(8)
# memory usage: 42.5+ KB

# %%
preprocessed_df.columns = ['date', 'title', 'url', '처벌','범죄_키워드','가해자_나이대','피해자','가해자']

# %%
preprocessed_df.head(50)
# Out:
#             date                                                 title  \
# 7    2022.01.26.                     결혼 1달 만에 아내 폭행·살해한 50대에 징역 30년 구형
# 38   2022.01.29.                  술주정·폭언·욕설 시달려 남편 살해한 60대 아내, '징역 4년'
# 80   2022.01.13.                       아내 용서에도…흉기로 살해한 40대 '징역 25년' 구형
# 86   2022.01.26.                      이혼 소송 중 장검으로 아내 살해한 40대에 무기징역 구형
# 91   2022.01.24.                   “왜 수익금 안 줘”…동업 친구 살해하려 한 20대 3명 징역형
# 92   2022.01.26.                혼인신고 한 달 뒤 아내 살해 혐의 50대… 검찰, 징역 30년 구형
# 95   2022.01.24.                 수익 배분에 불만 품고 동업하는 친구 살해 시도한 20대 징역 4년
# 116  2022.01.24.                  "왜 수익금 안 줘" 동업 친구 살해 시도 20대 3명 실형·집유
# 130  2022.01.26.                 장인 앞에서 아내 살해 40대男 "평생 속죄"...檢 무기징역 구형
# 136  2022.01.26.               장인 앞에서 아내 수십차례 찔러 살해한 40대, 검찰 ‘무기징역’ 구형
# 165  2022.01.26.                   장인 앞에서 일본도로 아내 살해한 40대…검찰 '무기징역' 구형
# 170  2022.01.26.  장인 앞에서 일본도로 아내 살해한 50대, 무기징역 구형 후 울먹이며 “평생 속죄하며 살겠다”
# 173  2022.01.24.                 혼자 수익금 관리 동업자 친구 살해 시도…20대 3명 실형·집행유예
# 196  2022.01.19.                    말다툼 중 격분해 지인 살해·암매장… 40대 남성 징역 18년
# 200  2022.01.19.                          말다툼 중 지인 살해 암매장한 40대에 징역 18년
# 294  2022.02.25.                    "나이 어리다고 무시해"...지인 살해한 50대에 징역 16년
# 296  2022.02.25.                           무시했다는 이유로 지인 살해한 50대 징역 16년
# 300  2022.02.17.                           폭행 용서해준 아내 살해한 40대 '징역 15년'
# 302  2022.02.23.                    홧김에 아내 둔기로 살해하려 한 70대, 2심도 '징역 3년'
# 317  2022.02.24.                  아내 장검으로 살해한 50대, 징역 20년에 항소…'검찰도 항소'
# 319  2022.02.15.                         "술 취해 자녀 안 돌봐" 아내 살해 30대 징역4년
# 322  2022.02.10.                “아들 돈 함부로 받지 말라” 다툼...아내 살해한 70대 징역 8년
# 333  2022.02.03.                         빚 독촉 시달리다 부모 살해 시도한 40대 징역 7년
# 334  2022.02.16.                     장인 앞에서 아내 일본도로 살해한 40대男, 오늘 1심 선고
# 338  2022.02.18.             장인 앞에서 일본칼로 아내 살해한 40대 남성, 징역 20년 판결받자 항소
# 341  2022.02.16.                        별거 중인 아내 흉기로 살해한 50대 남성 징역 20년
# 348  2022.02.11.          "술 조금만 먹으라" 꾸지람에 격분, 90대 노모 살해한 아들 징역 14년 확정
# 354  2022.02.10.             부모·형 살해한 30대... 경찰 “김씨 어머니, 지난해 3월 실종 신고”
# 359  2022.02.18.                            가정폭력 집행유예 중 아내 살해한 40대 징역형
# 371  2022.02.24.                  혼인신고 2년 만에 아내 살해한 40대… 법원, 징역 15년 선고
# 372  2022.02.22.                 "나를 인신매매할 것 같아서"…지인 살해 50대, 1심 징역 13년
# 376  2022.02.18.                  "바람피웠지" 수년간 의심…별거 아내 살해 60대 '징역 12년'
# 378  2022.02.17.                       잔소리 참지 못해 아내 흉기로 살해한 40대 징역 15년
# 382  2022.02.16.                이혼 소송 중 장검으로 아내 살해한 40대, 1심서 징역 20년 선고
# 384  2022.02.17.                                  아내 흉기로 살해 40대 징역 15년
# 385  2022.02.17.                        가정폭력 집유 기간 아내 살해 제주 40대 징역 15년
# 387  2022.02.18.                     '외도 의심' 별거중 아내 살해한 60대 남성, 징역 12년
# 388  2022.02.11.                       술 먹지 말랬다고 90대 노모 살해한 아들, 징역 14년
# 397  2022.02.10.                     아내 살해하고 "화 못 참았으니 심신미약"…70대 징역 8년
# 399  2022.02.17.                          제주, 말다툼 하다 아내 살해한 40대 징역 15년
# 402  2022.02.17.                       "잔소리했다고"…제주서 아내 살해 40대 '징역 15년'
# 409  2022.02.18.          장인 앞에서 아내 '일본도'로 살해한 40대... 징역 20년 판결 불복해 항소
# 416  2022.02.10.                        말다툼 끝에 아내 살해한 70대, 항소심서도 징역 8년
# 418  2022.02.10.                      "아들 돈 함부로 받지 마" 낮잠 자던 아내 살해한 70대
# 420  2022.02.11.               "술 조금만 마셔" 꾸지람에...90대 노모 살해한 아들, 징역 14년
# 421  2022.02.03.                  “빚 독촉에” 부모 살해미수 40대 아들…그래도 어머니는 용서했다
# 423  2022.02.10.                "아들 용돈 왜 받아"…말다툼 끝 아내 살해 70대 2심도 징역 8년
# 426  2022.02.11.                  “술 조금만 마셔” 90대 노모 살해한 50대 아들, 징역 14년
# 428  2022.02.16.                        '장인 앞에서 아내 살해' 40대 남성 1심서 20년형
# 432  2022.02.11.                         "아내 살해 기억 없어" 50대 항소심도 징역 18년
#
#                                                                                                                                      url  \
# 7                                                             http://www.newsis.com/view/?id=NISX20220126_0001738203&cID=10807&pID=10800
# 38                                                                                                https://www.news1.kr/articles/?4570429
# 80                                                                                              https://www.nocutnews.co.kr/news/5689758
# 86                                                                                  https://view.asiae.co.kr/article/2022012615490412989
# 91                                                           https://www.seoul.co.kr/news/newsView.php?id=20220124500042&wlog_tag3=naver
# 92                                                                         http://moneys.mt.co.kr/news/mwView.php?no=2022012613218073461
# 95                                                         http://www.segye.com/content/html/2022/01/24/20220124502333.html?OutUrl=naver
# 116                                                                        https://hankookilbo.com/News/Read/A2022012409190003646?did=NA
# 130                                                                               http://news.mt.co.kr/mtview.php?no=2022012616532912423
# 136                                                        http://www.segye.com/content/html/2022/01/26/20220126515897.html?OutUrl=naver
# 165                                                                                       https://www.ajunews.com/view/20220126211516300
# 170                                                        http://www.segye.com/content/html/2016/11/22/20161122503643.html?OutUrl=naver
# 173                                                                        http://www.munhwa.com/news/view.html?no=20220124MW08591198317
# 196                                                        http://www.segye.com/content/html/2022/01/19/20220119515673.html?OutUrl=naver
# 200                                                                                         http://yna.kr/AKR20220119126200053?did=1195m
# 294                                       https://www.pressian.com/pages/articles/2022022415493154351?utm_source=naver&utm_medium=search
# 296                                                                                https://news.kbs.co.kr/news/view.do?ncd=5403690&ref=A
# 300                                                                                             https://www.nocutnews.co.kr/news/5709103
# 302                                                           http://www.newsis.com/view/?id=NISX20220223_0001770297&cID=10803&pID=14000
# 317                                                                           http://www.hg-times.com/news/articleView.html?idxno=238824
# 319                                                                        http://www.yonhapnewstv.co.kr/MYH20220215021900038/?did=1825m
# 322                                                          https://www.seoul.co.kr/news/newsView.php?id=20220210500011&wlog_tag3=naver
# 333                                                        http://www.segye.com/content/html/2022/02/03/20220203502955.html?OutUrl=naver
# 334                                                                   http://www.edaily.co.kr/news/newspath.asp?newsid=01269366632231176
# 338                                                                        http://moneys.mt.co.kr/news/mwView.php?no=2022021810278037146
# 341                                                                                    https://www.ytn.co.kr/_ln/0103_202202161913230868
# 348                                                                                               https://www.news1.kr/articles/?4580718
# 354                                                          https://www.seoul.co.kr/news/newsView.php?id=20220210500107&wlog_tag3=naver
# 359                                                                                              https://jejumbc.com/article/G4u_zc7UgNw
# 371  https://biz.chosun.com/topics/law_firm/2022/02/24/KAACRBGRNZBBPH6DLWMC7IKY5Y/?utm_source=naver&utm_medium=original&utm_campaign=biz
# 372                                                                                               https://www.news1.kr/articles/?4593045
# 376                                                                                               https://www.news1.kr/articles/?4589446
# 378                                                        http://www.segye.com/content/html/2022/02/17/20220217512150.html?OutUrl=naver
# 382                                                                                 https://view.asiae.co.kr/article/2022021616073076854
# 384                                                                     http://www.jibs.co.kr/news/articles/articlesDetail/20911?feed=na
# 385                                                                           http://www.jejusori.net/news/articleView.html?idxno=338563
# 387                                                                 https://imnews.imbc.com/news/2022/society/article/6342843_35673.html
# 388                                                         http://news.kmib.co.kr/article/view.asp?arcid=0016760104&code=61121211&cp=nv
# 397                                                           http://www.newsis.com/view/?id=NISX20220209_0001752845&cID=10201&pID=10200
# 399                                                                     http://www.headlinejeju.co.kr/news/articleView.html?idxno=476668
# 402                                                                              http://www.jemin.com/news/articleView.html?idxno=732081
# 409                                                                                  http://www.ltn.kr/news/articleView.html?idxno=34238
# 416                                                        http://www.segye.com/content/html/2022/02/10/20220210503358.html?OutUrl=naver
# 418                                                    https://news.sbs.co.kr/news/endPage.do?news_id=N1006634951&plink=ORI&cooper=NAVER
# 420                                                    http://mbn.mk.co.kr/pages/news/newsView.php?category=mbn00009&news_seq_no=4697614
# 421                                                          https://www.seoul.co.kr/news/newsView.php?id=20220203500009&wlog_tag3=naver
# 423                                                                                               https://www.news1.kr/articles/?4579579
# 426                                                                     https://www.hani.co.kr/arti/society/society_general/1030703.html
# 428                                                                                      http://www.newspim.com/news/view/20220216000962
# 432                                                                            http://www.daejonilbo.com/news/newsitem.asp?pk_no=1506051
#
#            처벌                         범죄_키워드 가해자_나이대 피해자  가해자
# 7      징역 30년              결혼 아내 폭행 살해 징역 구형      50  아내   남편
# 38      징역 4년           주정 폭언 욕설 남편 살해 아내 징역      60  남편   아내
# 80     징역 25년              아내 용서 흉기 살해 징역 구형      40  아내   남편
# 86       무기징역         이혼 소송 장검 아내 살해 무기징역 구형      40  아내   남편
# 91                          수익금 동업 친구 살해 징역형      20  친구   친구
# 92     징역 30년         혼인신고 아내 살해 혐의 검찰 징역 구형      50  아내   남편
# 95      징역 4년        수익 배분 불만 동업 친구 살해 시도 징역      20  친구   친구
# 116       실형           수익금 동업 친구 살해 시도 실형 집유      20  친구   친구
# 130      무기징역         장인 아내 살해 평생 속죄 무기징역 구형      40  아내   남편
# 136      무기징역         장인 아내 차례 살해 검찰 무기징역 구형      40  아내   남편
# 165      무기징역        장인 일본도 아내 살해 검찰 무기징역 구형      40  아내   남편
# 170  무기징역 구형      장인 일본도 아내 살해 무기징역 구형 평생 속죄      50  아내   남편
# 173       실형   혼자 수익금 관리 업자 친구 살해 시도 실형 집행유예      20  친구   친구
# 196    징역 18년         말다툼 격분 지인 살해 암매장 남성 징역      40  지인   지인
# 200    징역 18년               말다툼 지인 살해 암매장 징역      40  지인   지인
# 294    징역 16년                 나이 무시 지인 살해 징역      50  지인   지인
# 296    징역 16년                 무시 이유 지인 살해 징역      50  지인   지인
# 300    징역 15년                 폭행 용서 아내 살해 징역      40  아내   남편
# 302     징역 3년                 홧김 아내 둔기 살해 징역      70  아내   남편
# 317    징역 20년           아내 장검 살해 징역 항소 검찰 항소      50  아내   남편
# 319      징역4년                 취해 자녀 아내 살해 징역      30  아내   남편
# 322     징역 8년             아들 함부로 다툼 아내 살해 징역      70  아내   남편
# 333     징역 7년                 독촉 부모 살해 시도 징역      40  부모   자식
# 334                       장인 아내 일본도 살해 오늘 선고      40  아내   남편
# 338    징역 20년           장인 아내 살해 남성 징역 판결 항소      40  아내   남편
# 341    징역 20년           별거 중인 아내 흉기 살해 남성 징역      50  아내   남편
# 348    징역 14년       조금 꾸지람 격분 노모 살해 아들 징역 확정      90  노모   아들
# 354                부모 살해 경찰 김씨 어머니 지난해 실종 신고      30  부모  어머니
# 359                      가정폭력 집행유예 아내 살해 징역형      40  아내   남편
# 371    징역 15년            혼인신고 아내 살해 법원 징역 선고      40  아내   남편
# 372    징역 13년                  인신매매 지인 살해 징역      50  지인   지인
# 376    징역 12년           바람 수년 의심 별거 아내 살해 징역      60  아내   남편
# 378    징역 15년                잔소리 아내 흉기 살해 징역      40  아내   남편
# 382    징역 20년           이혼 소송 장검 아내 살해 징역 선고      40  아내   남편
# 384    징역 15년                    아내 흉기 살해 징역      40  아내   남편
# 385    징역 15년         가정폭력 집유 기간 아내 살해 제주 징역      40  아내   남편
# 387    징역 12년           외도 의심 별거 아내 살해 남성 징역      60  아내   남편
# 388    징역 14년                말랬다 노모 살해 아들 징역      90  노모   아들
# 397     징역 8년                 아내 살해 심신 미약 징역      70  아내   남편
# 399    징역 15년                제주 말다툼 아내 살해 징역      40  아내   남편
# 402    징역 15년                잔소리 제주 아내 살해 징역      40  아내   남편
# 409    징역 20년       장인 아내 일본도 살해 징역 판결 불복 항소      40  아내   남편
# 416     징역 8년            말다툼 아내 살해 항소심 서도 징역      70  아내   남편
# 418                          아들 함부로 낮잠 아내 살해      70  아내   남편
# 420    징역 14년             조금 꾸지람 노모 살해 아들 징역      90  노모   아들
# 421                    독촉 부모 살해 미수 아들 어머니 용서      40  부모   아들
# 423     징역 8년             아들 용돈 말다툼 아내 살해 징역      70  아내   남편
# 426    징역 14년                 조금 노모 살해 아들 징역      50  노모   아들
# 428                              장인 아내 살해 남성      40  아내   남편
# 432    징역 18년                아내 살해 기억 항소심 징역      50  아내   남편

# %%
preprocessed_df.reset_index(drop=True, inplace=True)

# %%
preprocessed_df.to_csv('preprocessed_df.csv')

# %% [markdown]
# ## 같은 행에 다른 열에 있는 것들은 범죄 키워드에서 제거

# %%
for i in range(len(preprocessed_df)): # df 의 행 수만큼 for 문 돌린다.
    keywords = preprocessed_df.loc[i,'범죄_키워드'] # 컬럼만의 각 값을 순서대로 가져온다.
    print(keywords)
    keywords = keywords.split()

    for keyword in keywords:
        if keyword == preprocessed_df.loc[i,'피해자']:
            print(keyword)
            keywords.remove(keyword)
        
        if keyword == preprocessed_df.loc[i,'가해자']:
            keywords.remove(keyword)
        
        if keyword == '징역':
            keywords.remove(keyword)
            
            
    preprocessed_df.loc[i,'범죄_키워드']= keywords
# Out:
# ['결혼', '폭행', '살해', '구형']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/rn/pw4b6wxx5zs31m1t8h5y7ftr0000gn/T/ipykernel_52657/3620380611.py in <module>
#       2     keywords = preprocessed_df.loc[i,'범죄_키워드'] # 컬럼만의 각 값을 순서대로 가져온다.
#       3     print(keywords)
# ----> 4     keywords = keywords.split()
#       5
#       6     for keyword in keywords:
#
# AttributeError: 'list' object has no attribute 'split'

# %%
import re

for i in range(len(df)): # df 의 행 수만큼 for 문 돌린다.
    victim = df.loc[i,'nouns'] # 컬럼만의 각 값을 순서대로 가져온다.
    victim = list(victim.split())
    
    temp_li = []
    if '살해' in victim:
        index = victim.index('살해') #살해 라는 단어 후 단어들만 추출
        victim = victim[(index+1):]

        if len(victim) > 0:

            for v in victim:
                v = list(v.split())
                for j in v:
                    if j in list(crime_dict['person']):
                        temp_li.append(j)
                    
                            
    
    
    if len(temp_li) > 0:
        print(temp_li)
        temp_li = temp_li[0] #여러개 나올 경우 살해 바로 후 사람단어로 선택
        df.loc[i,'murderer']= temp_li
        
    else:
